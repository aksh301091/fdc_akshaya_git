# %%
# !pip install --upgrade pip
# !pip install "snowflake-connector-python[pandas]" "snowflake-snowpark-python[pandas]" snowflake-snowpark-python==1.9.0 fosforio fosforml numpy pandas matplotlib scikit-learn xgboost seaborn python-dateutil tqdm holidays faker
# !pip install --upgrade --q snowflake-snowpark-python==1.9.0
# !pip uninstall urllib3 -y
# !pip install urllib3==1.26.15

# %%
from fosforio import snowflake
from fosforio import get_dataframe
from datetime import datetime, timedelta
import numpy as np
# Out:
# Connection manager service url initialised to http://fdc-project-manager:80/project-manager
# If you need to update its value then update the variable CONNECTION_MANAGER_BASE_URL in os env.

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import seaborn as sns
# Out:
# Matplotlib created a temporary cache directory at /tmp/matplotlib-9x58bfwm because the default path (/home/mosaic-ai/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
snowflake.get_connection(connection_name="TTH_REV_OPT_CXN")
data = get_dataframe("BOOKINGS")
data
# Out:
# Connection object created: <snowflake.connector.connection.SnowflakeConnection object at 0x7fd1e47d2cd0>
# Please close the connection after use!
# Reading dataframe from snowflake native connector
#                HOTEL  IS_CANCELED  LEAD_TIME  ARRIVAL_DATE_YEAR  MONTH  \
# 0         City Hotel            0        226               2023      8
# 1       Resort Hotel            1        210               2024      3
# 2         City Hotel            1        127               2023      9
# 3       Resort Hotel            0         93               2023      8
# 4       Resort Hotel            0         18               2023      9
# ...              ...          ...        ...                ...    ...
# 117004    City Hotel            0         81               2023      8
# 117005    City Hotel            0         18               2023      8
# 117006    City Hotel            0         47               2023      8
# 117007    City Hotel            1         72               2023     10
# 117008  Resort Hotel            0        149               2023      8
#
#         ARRIVAL_DATE_WEEK_NUMBER  ARRIVAL_DATE_DAY_OF_MONTH  \
# 0                             35                         29
# 1                              9                          3
# 2                             37                         12
# 3                             34                         27
# 4                             35                          1
# ...                          ...                        ...
# 117004                        35                         30
# 117005                        35                         30
# 117006                        35                         31
# 117007                        42                         19
# 117008                        34                         26
#
#        EXPECTED_ARRIVAL_DATE RESERVATION_STATUS RESERVATION_STATUS_DATE  \
# 0                 2023-08-29          Check.Out              2023-01-15
# 1                 2024-03-03           Canceled              2023-08-06
# 2                 2023-09-12           Canceled              2023-05-08
# 3                 2023-08-27          Check.Out              2023-05-26
# 4                 2023-09-01          Check.Out              2023-08-14
# ...                      ...                ...                     ...
# 117004            2023-08-30          Check.Out              2023-06-10
# 117005            2023-08-30          Check.Out              2023-08-12
# 117006            2023-08-31          Check.Out              2023-07-15
# 117007            2023-10-19           Canceled              2023-08-08
# 117008            2023-08-26          Check.Out              2023-03-30
#
#         TOTAL_STAY_NIGHTS  TALLY_DAYS  STAYS_IN_WEEKEND_NIGHTS  \
# 0                       4       4.000                        2
# 1                       7       0.183                        2
# 2                       3       0.100                        2
# 3                       6       6.000                        2
# 4                       1       1.000                        0
# ...                   ...         ...                      ...
# 117004                  3       3.000                        2
# 117005                  3       3.000                        2
# 117006                  2       2.000                        1
# 117007                  4       0.470                        1
# 117008                  7       7.000                        2
#
#         STAYS_IN_WEEK_NIGHTS  ADULTS  CHILDREN  BABIES  TOTAL_GUESTS  \
# 0                          2       2         0       0             2
# 1                          5       2         0       0             2
# 2                          1       2         0       0             2
# 3                          4       2         0       0             2
# 4                          1       2         0       0             2
# ...                      ...     ...       ...     ...           ...
# 117004                     1       2         0       0             2
# 117005                     1       2         0       0             2
# 117006                     1       2         0       0             2
# 117007                     3       2         0       0             2
# 117008                     5       2         0       0             2
#
#         AVG_ROOMS_PER_NIGHT  TOTAL_ROOM_NIGHTS MEAL COUNTRY MARKET_SEGMENT  \
# 0                         1                  4   BB     FRA  Offline TA/TO
# 1                         1                  7   HB     PRT  Offline TA/TO
# 2                         1                  3   SC     BRA      Online TA
# 3                         1                  6   HB     AUT      Online TA
# 4                         1                  1   BB     ESP      Online TA
# ...                     ...                ...  ...     ...            ...
# 117004                    1                  3   BB     IRL         Direct
# 117005                    1                  3   SC     BEL      Online TA
# 117006                    1                  2   BB     PRT         Direct
# 117007                    1                  4   SC     FRA      Online TA
# 117008                    1                  7   BB     GBR      Online TA
#
#        DISTRIBUTION_CHANNEL  PREVIOUS_CANCELLATIONS  \
# 0                     TA/TO                       0
# 1                     TA/TO                       0
# 2                     TA/TO                       0
# 3                     TA/TO                       0
# 4                     TA/TO                       0
# ...                     ...                     ...
# 117004               Direct                       0
# 117005                  GDS                       0
# 117006               Direct                       0
# 117007                TA/TO                       0
# 117008                TA/TO                       0
#
#         PREVIOUS_BOOKINGS_NOT_CANCELED RESERVED_ROOM_TYPE ASSIGNED_ROOM_TYPE  \
# 0                                    0                  A                  A
# 1                                    0                  E                  E
# 2                                    0                  A                  A
# 3                                    0                  E                  E
# 4                                    0                  E                  E
# ...                                ...                ...                ...
# 117004                               0                  A                  A
# 117005                               0                  E                  E
# 117006                               0                  E                  E
# 117007                               0                  A                  A
# 117008                               0                  A                  A
#
#        DEPOSIT_TYPE  DAYS_IN_WAITING_LIST    CUSTOMER_TYPE     ADR
# 0        No Deposit                     0  Transient.Party   70.00
# 1        No Deposit                     0        Transient   90.00
# 2        No Deposit                     0        Transient   79.20
# 3        No Deposit                     0        Transient  102.93
# 4        No Deposit                     0  Transient.Party   80.00
# ...             ...                   ...              ...     ...
# 117004   No Deposit                     0        Transient   79.80
# 117005   No Deposit                     0        Transient  145.00
# 117006   No Deposit                     0        Transient  135.44
# 117007   No Deposit                     0        Transient   74.80
# 117008   No Deposit                     0        Transient   49.94
#
# [117009 rows x 32 columns]

# %%
data = pd.read_csv('./bookings_transformed_latest.csv')
data
# Out:
#         Unnamed: 0 arrival_date_transformed  \
# 0                0               2023-08-03
# 1                1               2023-08-02
# 2                2               2023-08-03
# 3                3               2023-07-29
# 4                4               2023-08-05
# ...            ...                      ...
# 109706      109706               2023-08-04
# 109707      109707               2023-07-30
# 109708      109708               2023-07-29
# 109709      109709               2023-08-01
# 109710      109710               2023-07-30
#
#        reservation_status_date_transformed         hotel  is_canceled  \
# 0                               2023-08-06    City Hotel            0
# 1                               2023-08-06  Resort Hotel            0
# 2                               2023-08-06    City Hotel            0
# 3                               2023-08-06    City Hotel            0
# 4                               2023-08-06    City Hotel            0
# ...                                    ...           ...          ...
# 109706                          2023-08-06    City Hotel            0
# 109707                          2023-08-06  Resort Hotel            0
# 109708                          2023-08-06    City Hotel            0
# 109709                          2023-08-06    City Hotel            0
# 109710                          2023-08-06  Resort Hotel            0
#
#         lead_time  arrival_date_year  month  arrival_date_week_number  \
# 0              86               2023      8                        31
# 1              10               2023      8                        31
# 2             180               2023      8                        31
# 3             148               2023      7                        30
# 4               0               2023      8                        31
# ...           ...                ...    ...                       ...
# 109706         11               2023      8                        31
# 109707        300               2023      7                        31
# 109708         69               2023      7                        30
# 109709        147               2023      8                        31
# 109710        300               2023      7                        31
#
#         arrival_date_day_of_month expected_arrival_date reservation_status  \
# 0                               3            03-08-2023          Check.Out
# 1                               2            02-08-2023          Check.Out
# 2                               3            03-08-2023          Check.Out
# 3                              29            29-07-2023          Check.Out
# 4                               5            05-08-2023          Check.Out
# ...                           ...                   ...                ...
# 109706                          4            04-08-2023          Check.Out
# 109707                         30            30-07-2023          Check.Out
# 109708                         29            29-07-2023          Check.Out
# 109709                          1            01-08-2023          Check.Out
# 109710                         30            30-07-2023          Check.Out
#
#        reservation_status_date  total_stay_nights  tally_days  \
# 0                   06-08-2023                  3         3.0
# 1                   06-08-2023                  4         4.0
# 2                   06-08-2023                  3         3.0
# 3                   06-08-2023                  8         8.0
# 4                   06-08-2023                  1         1.0
# ...                        ...                ...         ...
# 109706              06-08-2023                  2         2.0
# 109707              06-08-2023                  7         7.0
# 109708              06-08-2023                  8         8.0
# 109709              06-08-2023                  5         5.0
# 109710              06-08-2023                  7         7.0
#
#         stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# 0                             0                     3       3         0
# 1                             0                     4       2         0
# 2                             0                     3       2         0
# 3                             2                     6       2         0
# 4                             0                     1       1         0
# ...                         ...                   ...     ...       ...
# 109706                        0                     2       2         0
# 109707                        2                     5       2         0
# 109708                        2                     6       2         0
# 109709                        0                     5       3         0
# 109710                        2                     5       1         0
#
#         babies  total_guests  avg_rooms_per_night  total_room_nights meal  \
# 0            0             3                    1                  3   BB
# 1            0             2                    1                  4   BB
# 2            0             2                    1                  3   BB
# 3            0             2                    1                  8   SC
# 4            0             1                    1                  1   SC
# ...        ...           ...                  ...                ...  ...
# 109706       0             2                    1                  2   SC
# 109707       0             2                    1                  7   BB
# 109708       0             2                    1                  8   SC
# 109709       0             3                    1                  5   BB
# 109710       0             1                    1                  7   BB
#
#        country market_segment distribution_channel  previous_cancellations  \
# 0          DEU      Online TA                TA/TO                       0
# 1          PRT      Online TA                TA/TO                       0
# 2          GBR  Offline TA/TO                TA/TO                       0
# 3          FRA      Online TA                TA/TO                       0
# 4          FRA      Online TA                TA/TO                       0
# ...        ...            ...                  ...                     ...
# 109706     SLV      Online TA                TA/TO                       0
# 109707     PRT      Online TA                TA/TO                       0
# 109708     RUS      Online TA                TA/TO                       0
# 109709     SWE      Online TA                TA/TO                       0
# 109710     PRT      Online TA                TA/TO                       0
#
#         previous_bookings_not_canceled reserved_room_type assigned_room_type  \
# 0                                    0                  D                  D
# 1                                    0                  A                  A
# 2                                    0                  A                  A
# 3                                    0                  A                  A
# 4                                    0                  A                  A
# ...                                ...                ...                ...
# 109706                               0                  A                  A
# 109707                               0                  A                  A
# 109708                               0                  A                  A
# 109709                               0                  D                  D
# 109710                               0                  A                  A
#
#        deposit_type  days_in_waiting_list    customer_type     adr  \
# 0        No Deposit                     0        Transient  195.00
# 1        No Deposit                     0        Transient  228.50
# 2        No Deposit                     0        Transient   80.10
# 3        No Deposit                     0        Transient  121.88
# 4        No Deposit                     0        Transient  179.00
# ...             ...                   ...              ...     ...
# 109706   No Deposit                     0        Transient  160.00
# 109707   No Deposit                     0        Transient  149.81
# 109708   No Deposit                     0  Transient.Party  126.00
# 109709   No Deposit                     0        Transient  175.50
# 109710   No Deposit                     0  Transient.Party  149.81
#
#         transcation_ids   cust_id  room_limit
# 0       B20230803343215  C0106952          80
# 1       B20230802911470  C0106953         150
# 2       B20230803481168  C0106954         150
# 3       B20230729335744  C0106955         150
# 4       B20230805458332  C0106956         150
# ...                 ...       ...         ...
# 109706  B20230804347306  C0106947         150
# 109707  B20230730168488  C0106948         150
# 109708  B20230729444159  C0106949         150
# 109709  B20230801923755  C0106950          80
# 109710  B20230730847947  C0106951         150
#
# [109711 rows x 38 columns]

# %%
data.tail()
# Out:
#                HOTEL  IS_CANCELED  LEAD_TIME  ARRIVAL_DATE_YEAR  MONTH  \
# 117100  Resort Hotel            0        269               2023      8
# 117101  Resort Hotel            0        212               2023      8
# 117102  Resort Hotel            0        204               2023      8
# 117103  Resort Hotel            0        161               2023      8
# 117104  Resort Hotel            0        211               2023      8
#
#         ARRIVAL_DATE_WEEK_NUMBER  ARRIVAL_DATE_DAY_OF_MONTH  \
# 117100                        34                         24
# 117101                        35                         31
# 117102                        35                         29
# 117103                        35                         31
# 117104                        35                         31
#
#        EXPECTED_ARRIVAL_DATE RESERVATION_STATUS RESERVATION_STATUS_DATE  \
# 117100            2023-08-24          Check.Out              10-09-2023
# 117101            2023-08-31          Check.Out              10-09-2023
# 117102            2023-08-29          Check.Out              12-09-2023
# 117103            2023-08-31          Check.Out              14-09-2023
# 117104            2023-08-31          Check.Out              14-09-2023
#
#         TOTAL_STAY_NIGHTS  TALLY_DAYS  STAYS_IN_WEEKEND_NIGHTS  \
# 117100                 17        17.0                        4
# 117101                 10        10.0                        2
# 117102                 14        14.0                        4
# 117103                 14        14.0                        4
# 117104                 14        14.0                        4
#
#         STAYS_IN_WEEK_NIGHTS  ADULTS  CHILDREN  BABIES  TOTAL_GUESTS  \
# 117100                    13       2         0       0             2
# 117101                     8       2         1       0             3
# 117102                    10       2         0       0             2
# 117103                    10       2         0       0             2
# 117104                    10       2         0       0             2
#
#         AVG_ROOMS_PER_NIGHT  TOTAL_ROOM_NIGHTS MEAL COUNTRY MARKET_SEGMENT  \
# 117100                    1                 17   BB     GBR  Offline TA/TO
# 117101                    1                 10   BB     GBR  Offline TA/TO
# 117102                    1                 14   BB     IRL         Direct
# 117103                    1                 14   HB     DEU  Offline TA/TO
# 117104                    1                 14   HB     GBR  Offline TA/TO
#
#        DISTRIBUTION_CHANNEL  PREVIOUS_CANCELLATIONS  \
# 117100                TA/TO                       0
# 117101                TA/TO                       0
# 117102               Direct                       0
# 117103                TA/TO                       0
# 117104                TA/TO                       0
#
#         PREVIOUS_BOOKINGS_NOT_CANCELED RESERVED_ROOM_TYPE ASSIGNED_ROOM_TYPE  \
# 117100                               0                  D                  D
# 117101                               0                  A                  A
# 117102                               0                  E                  E
# 117103                               0                  A                  A
# 117104                               0                  D                  D
#
#        DEPOSIT_TYPE  DAYS_IN_WAITING_LIST CUSTOMER_TYPE     ADR
# 117100   No Deposit                     0      Contract   84.80
# 117101   No Deposit                     0     Transient   89.75
# 117102   No Deposit                     0     Transient  153.57
# 117103   No Deposit                     0     Transient   99.06
# 117104   No Deposit                     0      Contract  112.80

# %%
data['EXPECTED_ARRIVAL_DATE'] = pd.to_datetime(data['EXPECTED_ARRIVAL_DATE'], errors='coerce')
data['RESERVATION_STATUS_DATE'] = pd.to_datetime(data['RESERVATION_STATUS_DATE'], errors='coerce')
# Out:
# <ipython-input-5-a8ae016755e1>:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['RESERVATION_STATUS_DATE'] = pd.to_datetime(data['RESERVATION_STATUS_DATE'], errors='coerce')

# %%
data['LEAD_TIME'].min()
# Out:
# 0

# %%
data['LEAD_TIME'].max()
# Out:
# 709

# %%
data['LEAD_TIME'].mean()
# Out:
# 105.19527774219718

# %%
pd.to_datetime(data['EXPECTED_ARRIVAL_DATE']).min()
# Out:
# Timestamp('2021-07-01 00:00:00')

# %%
pd.to_datetime(data['EXPECTED_ARRIVAL_DATE']).max()
# Out:
# Timestamp('2023-08-31 00:00:00')

# %%
original_last_date = datetime(2023, 8, 31)
target_date = datetime(2024, 6, 30)

# %%
original_min_date = data['EXPECTED_ARRIVAL_DATE'].min()
original_min_date
# Out:
# Timestamp('2021-07-01 00:00:00')

# %%
days_to_add = (target_date - original_last_date).days
days_to_add
# Out:
# 304

# %%
data['NEW_RES_TIME'] = 0
for index, row in data.iterrows():
    data['NEW_RES_TIME'].iloc[index] = data['EXPECTED_ARRIVAL_DATE'].iloc[index] - timedelta(days=int(data['LEAD_TIME'].iloc[index]))
# Out:
# <ipython-input-14-49002dfdab68>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['NEW_RES_TIME'].iloc[index] = data['EXPECTED_ARRIVAL_DATE'].iloc[index] - timedelta(days=int(data['LEAD_TIME'].iloc[index]))

# %%
data['NEW_RES_TIME']
# Out:
# 0         2020-10-17 00:00:00
# 1         2020-10-17 00:00:00
# 2         2020-10-17 00:00:00
# 3         2020-10-17 00:00:00
# 4         2020-10-17 00:00:00
#                  ...
# 117100    2022-11-28 00:00:00
# 117101    2023-01-31 00:00:00
# 117102    2023-02-06 00:00:00
# 117103    2023-03-23 00:00:00
# 117104    2023-02-01 00:00:00
# Name: NEW_RES_TIME, Length: 117105, dtype: object

# %%
data['EXPECTED_ARRIVAL_DATE'] = data['EXPECTED_ARRIVAL_DATE'] + timedelta(days=days_to_add)
data['RESERVATION_STATUS_DATE'] = data['NEW_RES_TIME'] + timedelta(days=days_to_add)

# %%
data['LEAD_TIME_UPDATED'] = data['EXPECTED_ARRIVAL_DATE'] - data['RESERVATION_STATUS_DATE']
# Out:
# <ipython-input-17-23265ab83679>:1: PerformanceWarning: Adding/subtracting object-dtype array to DatetimeArray not vectorized.
#   data['LEAD_TIME_UPDATED'] = data['EXPECTED_ARRIVAL_DATE'] - data['RESERVATION_STATUS_DATE']

# %%
data['EXPECTED_ARRIVAL_DATE'].min()
# Out:
# Timestamp('2022-05-01 00:00:00')

# %%
data['EXPECTED_ARRIVAL_DATE'].max()
# Out:
# Timestamp('2024-06-30 00:00:00')

# %%
data['LEAD_TIME_UPDATED']  = pd.to_timedelta(data['LEAD_TIME_UPDATED']).dt.days

# %%
data['LEAD_TIME_UPDATED'].max()
# Out:
# 709.0

# %%
data['LEAD_TIME_UPDATED'].min()
# Out:
# 0.0

# %%
data['LEAD_TIME_UPDATED'].mean()
# Out:
# 105.23548615918433

# %%
data.isna().sum()
# Out:
# HOTEL                              0
# IS_CANCELED                        0
# LEAD_TIME                          0
# ARRIVAL_DATE_YEAR                  0
# MONTH                              0
# ARRIVAL_DATE_WEEK_NUMBER           0
# ARRIVAL_DATE_DAY_OF_MONTH          0
# EXPECTED_ARRIVAL_DATE             96
# RESERVATION_STATUS                 0
# RESERVATION_STATUS_DATE           96
# TOTAL_STAY_NIGHTS                  0
# TALLY_DAYS                         0
# STAYS_IN_WEEKEND_NIGHTS            0
# STAYS_IN_WEEK_NIGHTS               0
# ADULTS                             0
# CHILDREN                           0
# BABIES                             0
# TOTAL_GUESTS                       0
# AVG_ROOMS_PER_NIGHT                0
# TOTAL_ROOM_NIGHTS                  0
# MEAL                               0
# COUNTRY                            0
# MARKET_SEGMENT                     0
# DISTRIBUTION_CHANNEL               0
# PREVIOUS_CANCELLATIONS             0
# PREVIOUS_BOOKINGS_NOT_CANCELED     0
# RESERVED_ROOM_TYPE                 0
# ASSIGNED_ROOM_TYPE                 0
# DEPOSIT_TYPE                       0
# DAYS_IN_WAITING_LIST               0
# CUSTOMER_TYPE                      0
# ADR                                0
# NEW_RES_TIME                      96
# LEAD_TIME_UPDATED                 96
# dtype: int64

# %%
data
# Out:
#                HOTEL  IS_CANCELED  LEAD_TIME  ARRIVAL_DATE_YEAR  MONTH  \
# 0         City Hotel            1        272               2021      7
# 1         City Hotel            1        307               2021      8
# 2         City Hotel            1        258               2021      7
# 3         City Hotel            1        307               2021      8
# 4         City Hotel            1        279               2021      7
# ...              ...          ...        ...                ...    ...
# 117100  Resort Hotel            0        269               2023      8
# 117101  Resort Hotel            0        212               2023      8
# 117102  Resort Hotel            0        204               2023      8
# 117103  Resort Hotel            0        161               2023      8
# 117104  Resort Hotel            0        211               2023      8
#
#         ARRIVAL_DATE_WEEK_NUMBER  ARRIVAL_DATE_DAY_OF_MONTH  \
# 0                             29                         16
# 1                             34                         20
# 2                             27                          2
# 3                             34                         20
# 4                             30                         23
# ...                          ...                        ...
# 117100                        34                         24
# 117101                        35                         31
# 117102                        35                         29
# 117103                        35                         31
# 117104                        35                         31
#
#        EXPECTED_ARRIVAL_DATE RESERVATION_STATUS RESERVATION_STATUS_DATE  \
# 0                 2022-05-16           Canceled     2021-08-17 00:00:00
# 1                 2022-06-20           Canceled     2021-08-17 00:00:00
# 2                 2022-05-02           Canceled     2021-08-17 00:00:00
# 3                 2022-06-20           Canceled     2021-08-17 00:00:00
# 4                 2022-05-23           Canceled     2021-08-17 00:00:00
# ...                      ...                ...                     ...
# 117100            2024-06-23          Check.Out     2023-09-28 00:00:00
# 117101            2024-06-30          Check.Out     2023-12-01 00:00:00
# 117102            2024-06-28          Check.Out     2023-12-07 00:00:00
# 117103            2024-06-30          Check.Out     2024-01-21 00:00:00
# 117104            2024-06-30          Check.Out     2023-12-02 00:00:00
#
#         TOTAL_STAY_NIGHTS  TALLY_DAYS  STAYS_IN_WEEKEND_NIGHTS  \
# 0                       2       0.272                        0
# 1                       2       0.307                        0
# 2                       2       0.258                        0
# 3                       2       0.307                        0
# 4                       2       0.279                        0
# ...                   ...         ...                      ...
# 117100                 17      17.000                        4
# 117101                 10      10.000                        2
# 117102                 14      14.000                        4
# 117103                 14      14.000                        4
# 117104                 14      14.000                        4
#
#         STAYS_IN_WEEK_NIGHTS  ADULTS  CHILDREN  BABIES  TOTAL_GUESTS  \
# 0                          2       2         0       0             2
# 1                          2       2         0       0             2
# 2                          2       2         0       0             2
# 3                          2       2         0       0             2
# 4                          2       2         0       0             2
# ...                      ...     ...       ...     ...           ...
# 117100                    13       2         0       0             2
# 117101                     8       2         1       0             3
# 117102                    10       2         0       0             2
# 117103                    10       2         0       0             2
# 117104                    10       2         0       0             2
#
#         AVG_ROOMS_PER_NIGHT  TOTAL_ROOM_NIGHTS MEAL COUNTRY MARKET_SEGMENT  \
# 0                         1                  2   BB     PRT         Groups
# 1                         1                  2   BB     PRT         Groups
# 2                         1                  2   BB     PRT         Groups
# 3                         1                  2   BB     PRT         Groups
# 4                         1                  2   BB     PRT         Groups
# ...                     ...                ...  ...     ...            ...
# 117100                    1                 17   BB     GBR  Offline TA/TO
# 117101                    1                 10   BB     GBR  Offline TA/TO
# 117102                    1                 14   BB     IRL         Direct
# 117103                    1                 14   HB     DEU  Offline TA/TO
# 117104                    1                 14   HB     GBR  Offline TA/TO
#
#        DISTRIBUTION_CHANNEL  PREVIOUS_CANCELLATIONS  \
# 0                     TA/TO                       1
# 1                     TA/TO                       1
# 2                     TA/TO                       1
# 3                     TA/TO                       1
# 4                     TA/TO                       1
# ...                     ...                     ...
# 117100                TA/TO                       0
# 117101                TA/TO                       0
# 117102               Direct                       0
# 117103                TA/TO                       0
# 117104                TA/TO                       0
#
#         PREVIOUS_BOOKINGS_NOT_CANCELED RESERVED_ROOM_TYPE ASSIGNED_ROOM_TYPE  \
# 0                                    0                  A                  A
# 1                                    0                  A                  A
# 2                                    0                  A                  A
# 3                                    0                  A                  A
# 4                                    0                  A                  A
# ...                                ...                ...                ...
# 117100                               0                  D                  D
# 117101                               0                  A                  A
# 117102                               0                  E                  E
# 117103                               0                  A                  A
# 117104                               0                  D                  D
#
#        DEPOSIT_TYPE  DAYS_IN_WAITING_LIST    CUSTOMER_TYPE     ADR  \
# 0        No Deposit                     0  Transient.Party   62.80
# 1        No Deposit                     0  Transient.Party   62.80
# 2        No Deposit                     0  Transient.Party   62.80
# 3        No Deposit                     0  Transient.Party   62.80
# 4        No Deposit                     0  Transient.Party   62.80
# ...             ...                   ...              ...     ...
# 117100   No Deposit                     0         Contract   84.80
# 117101   No Deposit                     0        Transient   89.75
# 117102   No Deposit                     0        Transient  153.57
# 117103   No Deposit                     0        Transient   99.06
# 117104   No Deposit                     0         Contract  112.80
#
#                NEW_RES_TIME  LEAD_TIME_UPDATED
# 0       2020-10-17 00:00:00              272.0
# 1       2020-10-17 00:00:00              307.0
# 2       2020-10-17 00:00:00              258.0
# 3       2020-10-17 00:00:00              307.0
# 4       2020-10-17 00:00:00              279.0
# ...                     ...                ...
# 117100  2022-11-28 00:00:00              269.0
# 117101  2023-01-31 00:00:00              212.0
# 117102  2023-02-06 00:00:00              204.0
# 117103  2023-03-23 00:00:00              161.0
# 117104  2023-02-01 00:00:00              211.0
#
# [117105 rows x 34 columns]

# %%
data['LEAD_TIME'] = data['LEAD_TIME_UPDATED']

# %%
data['EXPECTED_ARRIVAL_DATE'].dt.year
# Out:
# 0         2022.0
# 1         2022.0
# 2         2022.0
# 3         2022.0
# 4         2022.0
#            ...
# 117100    2024.0
# 117101    2024.0
# 117102    2024.0
# 117103    2024.0
# 117104    2024.0
# Name: EXPECTED_ARRIVAL_DATE, Length: 117105, dtype: float64

# %%
data['EXPECTED_ARRIVAL_DATE'].dt.month
# Out:
# 0         5.0
# 1         6.0
# 2         5.0
# 3         6.0
# 4         5.0
#          ...
# 117100    6.0
# 117101    6.0
# 117102    6.0
# 117103    6.0
# 117104    6.0
# Name: EXPECTED_ARRIVAL_DATE, Length: 117105, dtype: float64

# %%
data['EXPECTED_ARRIVAL_DATE'].dt.isocalendar().week
# Out:
# 0         20
# 1         25
# 2         18
# 3         25
# 4         21
#           ..
# 117100    25
# 117101    26
# 117102    26
# 117103    26
# 117104    26
# Name: week, Length: 117105, dtype: UInt32

# %%
data['EXPECTED_ARRIVAL_DATE'].dt.month
# Out:
# 0         5.0
# 1         6.0
# 2         5.0
# 3         6.0
# 4         5.0
#          ...
# 117100    6.0
# 117101    6.0
# 117102    6.0
# 117103    6.0
# 117104    6.0
# Name: EXPECTED_ARRIVAL_DATE, Length: 117105, dtype: float64

# %%
data['ARRIVAL_DATE_YEAR'] = data['EXPECTED_ARRIVAL_DATE'].dt.year
data['ARRIVAL_DATE_WEEK_NUMBER'] = data['EXPECTED_ARRIVAL_DATE'].dt.isocalendar().week
data['ARRIVAL_DATE_DAY_OF_MONTH'] = data['EXPECTED_ARRIVAL_DATE'].dt.day
data['MONTH'] = data['EXPECTED_ARRIVAL_DATE'].dt.month

# %%
data['EXPECTED_ARRIVAL_DATE'].min()
# Out:
# Timestamp('2022-05-01 00:00:00')

# %%
data['EXPECTED_ARRIVAL_DATE'].max()
# Out:
# Timestamp('2024-06-30 00:00:00')

# %%
data['EXPECTED_ARRIVAL_DATE'].min()
# Out:
# Timestamp('2022-05-01 00:00:00')

# %%
data['EXPECTED_ARRIVAL_DATE'].max()
# Out:
# Timestamp('2024-06-30 00:00:00')

# %%
data_backup = data.dropna(axis=0)
data_backup
# Out:
#                HOTEL  IS_CANCELED  LEAD_TIME  ARRIVAL_DATE_YEAR  MONTH  \
# 0         City Hotel            1      272.0             2022.0    5.0
# 1         City Hotel            1      307.0             2022.0    6.0
# 2         City Hotel            1      258.0             2022.0    5.0
# 3         City Hotel            1      307.0             2022.0    6.0
# 4         City Hotel            1      279.0             2022.0    5.0
# ...              ...          ...        ...                ...    ...
# 117100  Resort Hotel            0      269.0             2024.0    6.0
# 117101  Resort Hotel            0      212.0             2024.0    6.0
# 117102  Resort Hotel            0      204.0             2024.0    6.0
# 117103  Resort Hotel            0      161.0             2024.0    6.0
# 117104  Resort Hotel            0      211.0             2024.0    6.0
#
#         ARRIVAL_DATE_WEEK_NUMBER  ARRIVAL_DATE_DAY_OF_MONTH  \
# 0                             20                       16.0
# 1                             25                       20.0
# 2                             18                        2.0
# 3                             25                       20.0
# 4                             21                       23.0
# ...                          ...                        ...
# 117100                        25                       23.0
# 117101                        26                       30.0
# 117102                        26                       28.0
# 117103                        26                       30.0
# 117104                        26                       30.0
#
#        EXPECTED_ARRIVAL_DATE RESERVATION_STATUS RESERVATION_STATUS_DATE  \
# 0                 2022-05-16           Canceled     2021-08-17 00:00:00
# 1                 2022-06-20           Canceled     2021-08-17 00:00:00
# 2                 2022-05-02           Canceled     2021-08-17 00:00:00
# 3                 2022-06-20           Canceled     2021-08-17 00:00:00
# 4                 2022-05-23           Canceled     2021-08-17 00:00:00
# ...                      ...                ...                     ...
# 117100            2024-06-23          Check.Out     2023-09-28 00:00:00
# 117101            2024-06-30          Check.Out     2023-12-01 00:00:00
# 117102            2024-06-28          Check.Out     2023-12-07 00:00:00
# 117103            2024-06-30          Check.Out     2024-01-21 00:00:00
# 117104            2024-06-30          Check.Out     2023-12-02 00:00:00
#
#         TOTAL_STAY_NIGHTS  TALLY_DAYS  STAYS_IN_WEEKEND_NIGHTS  \
# 0                       2       0.272                        0
# 1                       2       0.307                        0
# 2                       2       0.258                        0
# 3                       2       0.307                        0
# 4                       2       0.279                        0
# ...                   ...         ...                      ...
# 117100                 17      17.000                        4
# 117101                 10      10.000                        2
# 117102                 14      14.000                        4
# 117103                 14      14.000                        4
# 117104                 14      14.000                        4
#
#         STAYS_IN_WEEK_NIGHTS  ADULTS  CHILDREN  BABIES  TOTAL_GUESTS  \
# 0                          2       2         0       0             2
# 1                          2       2         0       0             2
# 2                          2       2         0       0             2
# 3                          2       2         0       0             2
# 4                          2       2         0       0             2
# ...                      ...     ...       ...     ...           ...
# 117100                    13       2         0       0             2
# 117101                     8       2         1       0             3
# 117102                    10       2         0       0             2
# 117103                    10       2         0       0             2
# 117104                    10       2         0       0             2
#
#         AVG_ROOMS_PER_NIGHT  TOTAL_ROOM_NIGHTS MEAL COUNTRY MARKET_SEGMENT  \
# 0                         1                  2   BB     PRT         Groups
# 1                         1                  2   BB     PRT         Groups
# 2                         1                  2   BB     PRT         Groups
# 3                         1                  2   BB     PRT         Groups
# 4                         1                  2   BB     PRT         Groups
# ...                     ...                ...  ...     ...            ...
# 117100                    1                 17   BB     GBR  Offline TA/TO
# 117101                    1                 10   BB     GBR  Offline TA/TO
# 117102                    1                 14   BB     IRL         Direct
# 117103                    1                 14   HB     DEU  Offline TA/TO
# 117104                    1                 14   HB     GBR  Offline TA/TO
#
#        DISTRIBUTION_CHANNEL  PREVIOUS_CANCELLATIONS  \
# 0                     TA/TO                       1
# 1                     TA/TO                       1
# 2                     TA/TO                       1
# 3                     TA/TO                       1
# 4                     TA/TO                       1
# ...                     ...                     ...
# 117100                TA/TO                       0
# 117101                TA/TO                       0
# 117102               Direct                       0
# 117103                TA/TO                       0
# 117104                TA/TO                       0
#
#         PREVIOUS_BOOKINGS_NOT_CANCELED RESERVED_ROOM_TYPE ASSIGNED_ROOM_TYPE  \
# 0                                    0                  A                  A
# 1                                    0                  A                  A
# 2                                    0                  A                  A
# 3                                    0                  A                  A
# 4                                    0                  A                  A
# ...                                ...                ...                ...
# 117100                               0                  D                  D
# 117101                               0                  A                  A
# 117102                               0                  E                  E
# 117103                               0                  A                  A
# 117104                               0                  D                  D
#
#        DEPOSIT_TYPE  DAYS_IN_WAITING_LIST    CUSTOMER_TYPE     ADR  \
# 0        No Deposit                     0  Transient.Party   62.80
# 1        No Deposit                     0  Transient.Party   62.80
# 2        No Deposit                     0  Transient.Party   62.80
# 3        No Deposit                     0  Transient.Party   62.80
# 4        No Deposit                     0  Transient.Party   62.80
# ...             ...                   ...              ...     ...
# 117100   No Deposit                     0         Contract   84.80
# 117101   No Deposit                     0        Transient   89.75
# 117102   No Deposit                     0        Transient  153.57
# 117103   No Deposit                     0        Transient   99.06
# 117104   No Deposit                     0         Contract  112.80
#
#                NEW_RES_TIME  LEAD_TIME_UPDATED
# 0       2020-10-17 00:00:00              272.0
# 1       2020-10-17 00:00:00              307.0
# 2       2020-10-17 00:00:00              258.0
# 3       2020-10-17 00:00:00              307.0
# 4       2020-10-17 00:00:00              279.0
# ...                     ...                ...
# 117100  2022-11-28 00:00:00              269.0
# 117101  2023-01-31 00:00:00              212.0
# 117102  2023-02-06 00:00:00              204.0
# 117103  2023-03-23 00:00:00              161.0
# 117104  2023-02-01 00:00:00              211.0
#
# [117009 rows x 34 columns]

# %%
data_backup[['LEAD_TIME', 'ARRIVAL_DATE_YEAR', 'ARRIVAL_DATE_DAY_OF_MONTH', 'MONTH']] = data_backup[['LEAD_TIME', 'ARRIVAL_DATE_YEAR', 'ARRIVAL_DATE_DAY_OF_MONTH', 'MONTH']].astype(int)
# Out:
# <ipython-input-39-c43e67327d73>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_backup[['LEAD_TIME', 'ARRIVAL_DATE_YEAR', 'ARRIVAL_DATE_DAY_OF_MONTH', 'MONTH']] = data_backup[['LEAD_TIME', 'ARRIVAL_DATE_YEAR', 'ARRIVAL_DATE_DAY_OF_MONTH', 'MONTH']].astype(int)

# %%
data_backup
# Out:
#                HOTEL  IS_CANCELED  LEAD_TIME  ARRIVAL_DATE_YEAR  MONTH  \
# 0         City Hotel            1        272               2022      5
# 1         City Hotel            1        307               2022      6
# 2         City Hotel            1        258               2022      5
# 3         City Hotel            1        307               2022      6
# 4         City Hotel            1        279               2022      5
# ...              ...          ...        ...                ...    ...
# 117100  Resort Hotel            0        269               2024      6
# 117101  Resort Hotel            0        212               2024      6
# 117102  Resort Hotel            0        204               2024      6
# 117103  Resort Hotel            0        161               2024      6
# 117104  Resort Hotel            0        211               2024      6
#
#         ARRIVAL_DATE_WEEK_NUMBER  ARRIVAL_DATE_DAY_OF_MONTH  \
# 0                             20                         16
# 1                             25                         20
# 2                             18                          2
# 3                             25                         20
# 4                             21                         23
# ...                          ...                        ...
# 117100                        25                         23
# 117101                        26                         30
# 117102                        26                         28
# 117103                        26                         30
# 117104                        26                         30
#
#        EXPECTED_ARRIVAL_DATE RESERVATION_STATUS RESERVATION_STATUS_DATE  \
# 0                 2022-05-16           Canceled     2021-08-17 00:00:00
# 1                 2022-06-20           Canceled     2021-08-17 00:00:00
# 2                 2022-05-02           Canceled     2021-08-17 00:00:00
# 3                 2022-06-20           Canceled     2021-08-17 00:00:00
# 4                 2022-05-23           Canceled     2021-08-17 00:00:00
# ...                      ...                ...                     ...
# 117100            2024-06-23          Check.Out     2023-09-28 00:00:00
# 117101            2024-06-30          Check.Out     2023-12-01 00:00:00
# 117102            2024-06-28          Check.Out     2023-12-07 00:00:00
# 117103            2024-06-30          Check.Out     2024-01-21 00:00:00
# 117104            2024-06-30          Check.Out     2023-12-02 00:00:00
#
#         TOTAL_STAY_NIGHTS  TALLY_DAYS  STAYS_IN_WEEKEND_NIGHTS  \
# 0                       2       0.272                        0
# 1                       2       0.307                        0
# 2                       2       0.258                        0
# 3                       2       0.307                        0
# 4                       2       0.279                        0
# ...                   ...         ...                      ...
# 117100                 17      17.000                        4
# 117101                 10      10.000                        2
# 117102                 14      14.000                        4
# 117103                 14      14.000                        4
# 117104                 14      14.000                        4
#
#         STAYS_IN_WEEK_NIGHTS  ADULTS  CHILDREN  BABIES  TOTAL_GUESTS  \
# 0                          2       2         0       0             2
# 1                          2       2         0       0             2
# 2                          2       2         0       0             2
# 3                          2       2         0       0             2
# 4                          2       2         0       0             2
# ...                      ...     ...       ...     ...           ...
# 117100                    13       2         0       0             2
# 117101                     8       2         1       0             3
# 117102                    10       2         0       0             2
# 117103                    10       2         0       0             2
# 117104                    10       2         0       0             2
#
#         AVG_ROOMS_PER_NIGHT  TOTAL_ROOM_NIGHTS MEAL COUNTRY MARKET_SEGMENT  \
# 0                         1                  2   BB     PRT         Groups
# 1                         1                  2   BB     PRT         Groups
# 2                         1                  2   BB     PRT         Groups
# 3                         1                  2   BB     PRT         Groups
# 4                         1                  2   BB     PRT         Groups
# ...                     ...                ...  ...     ...            ...
# 117100                    1                 17   BB     GBR  Offline TA/TO
# 117101                    1                 10   BB     GBR  Offline TA/TO
# 117102                    1                 14   BB     IRL         Direct
# 117103                    1                 14   HB     DEU  Offline TA/TO
# 117104                    1                 14   HB     GBR  Offline TA/TO
#
#        DISTRIBUTION_CHANNEL  PREVIOUS_CANCELLATIONS  \
# 0                     TA/TO                       1
# 1                     TA/TO                       1
# 2                     TA/TO                       1
# 3                     TA/TO                       1
# 4                     TA/TO                       1
# ...                     ...                     ...
# 117100                TA/TO                       0
# 117101                TA/TO                       0
# 117102               Direct                       0
# 117103                TA/TO                       0
# 117104                TA/TO                       0
#
#         PREVIOUS_BOOKINGS_NOT_CANCELED RESERVED_ROOM_TYPE ASSIGNED_ROOM_TYPE  \
# 0                                    0                  A                  A
# 1                                    0                  A                  A
# 2                                    0                  A                  A
# 3                                    0                  A                  A
# 4                                    0                  A                  A
# ...                                ...                ...                ...
# 117100                               0                  D                  D
# 117101                               0                  A                  A
# 117102                               0                  E                  E
# 117103                               0                  A                  A
# 117104                               0                  D                  D
#
#        DEPOSIT_TYPE  DAYS_IN_WAITING_LIST    CUSTOMER_TYPE     ADR  \
# 0        No Deposit                     0  Transient.Party   62.80
# 1        No Deposit                     0  Transient.Party   62.80
# 2        No Deposit                     0  Transient.Party   62.80
# 3        No Deposit                     0  Transient.Party   62.80
# 4        No Deposit                     0  Transient.Party   62.80
# ...             ...                   ...              ...     ...
# 117100   No Deposit                     0         Contract   84.80
# 117101   No Deposit                     0        Transient   89.75
# 117102   No Deposit                     0        Transient  153.57
# 117103   No Deposit                     0        Transient   99.06
# 117104   No Deposit                     0         Contract  112.80
#
#                NEW_RES_TIME  LEAD_TIME_UPDATED
# 0       2020-10-17 00:00:00              272.0
# 1       2020-10-17 00:00:00              307.0
# 2       2020-10-17 00:00:00              258.0
# 3       2020-10-17 00:00:00              307.0
# 4       2020-10-17 00:00:00              279.0
# ...                     ...                ...
# 117100  2022-11-28 00:00:00              269.0
# 117101  2023-01-31 00:00:00              212.0
# 117102  2023-02-06 00:00:00              204.0
# 117103  2023-03-23 00:00:00              161.0
# 117104  2023-02-01 00:00:00              211.0
#
# [117009 rows x 34 columns]

# %%
data_backup.drop(["NEW_RES_TIME", "LEAD_TIME_UPDATED"], axis=1, inplace=True)
# Out:
# <ipython-input-41-84b76b232090>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_backup.drop(["NEW_RES_TIME", "LEAD_TIME_UPDATED"], axis=1, inplace=True)

# %%
data_backup
# Out:
#                HOTEL  IS_CANCELED  LEAD_TIME  ARRIVAL_DATE_YEAR  MONTH  \
# 0         City Hotel            1        272               2022      5
# 1         City Hotel            1        307               2022      6
# 2         City Hotel            1        258               2022      5
# 3         City Hotel            1        307               2022      6
# 4         City Hotel            1        279               2022      5
# ...              ...          ...        ...                ...    ...
# 117100  Resort Hotel            0        269               2024      6
# 117101  Resort Hotel            0        212               2024      6
# 117102  Resort Hotel            0        204               2024      6
# 117103  Resort Hotel            0        161               2024      6
# 117104  Resort Hotel            0        211               2024      6
#
#         ARRIVAL_DATE_WEEK_NUMBER  ARRIVAL_DATE_DAY_OF_MONTH  \
# 0                             20                         16
# 1                             25                         20
# 2                             18                          2
# 3                             25                         20
# 4                             21                         23
# ...                          ...                        ...
# 117100                        25                         23
# 117101                        26                         30
# 117102                        26                         28
# 117103                        26                         30
# 117104                        26                         30
#
#        EXPECTED_ARRIVAL_DATE RESERVATION_STATUS RESERVATION_STATUS_DATE  \
# 0                 2022-05-16           Canceled     2021-08-17 00:00:00
# 1                 2022-06-20           Canceled     2021-08-17 00:00:00
# 2                 2022-05-02           Canceled     2021-08-17 00:00:00
# 3                 2022-06-20           Canceled     2021-08-17 00:00:00
# 4                 2022-05-23           Canceled     2021-08-17 00:00:00
# ...                      ...                ...                     ...
# 117100            2024-06-23          Check.Out     2023-09-28 00:00:00
# 117101            2024-06-30          Check.Out     2023-12-01 00:00:00
# 117102            2024-06-28          Check.Out     2023-12-07 00:00:00
# 117103            2024-06-30          Check.Out     2024-01-21 00:00:00
# 117104            2024-06-30          Check.Out     2023-12-02 00:00:00
#
#         TOTAL_STAY_NIGHTS  TALLY_DAYS  STAYS_IN_WEEKEND_NIGHTS  \
# 0                       2       0.272                        0
# 1                       2       0.307                        0
# 2                       2       0.258                        0
# 3                       2       0.307                        0
# 4                       2       0.279                        0
# ...                   ...         ...                      ...
# 117100                 17      17.000                        4
# 117101                 10      10.000                        2
# 117102                 14      14.000                        4
# 117103                 14      14.000                        4
# 117104                 14      14.000                        4
#
#         STAYS_IN_WEEK_NIGHTS  ADULTS  CHILDREN  BABIES  TOTAL_GUESTS  \
# 0                          2       2         0       0             2
# 1                          2       2         0       0             2
# 2                          2       2         0       0             2
# 3                          2       2         0       0             2
# 4                          2       2         0       0             2
# ...                      ...     ...       ...     ...           ...
# 117100                    13       2         0       0             2
# 117101                     8       2         1       0             3
# 117102                    10       2         0       0             2
# 117103                    10       2         0       0             2
# 117104                    10       2         0       0             2
#
#         AVG_ROOMS_PER_NIGHT  TOTAL_ROOM_NIGHTS MEAL COUNTRY MARKET_SEGMENT  \
# 0                         1                  2   BB     PRT         Groups
# 1                         1                  2   BB     PRT         Groups
# 2                         1                  2   BB     PRT         Groups
# 3                         1                  2   BB     PRT         Groups
# 4                         1                  2   BB     PRT         Groups
# ...                     ...                ...  ...     ...            ...
# 117100                    1                 17   BB     GBR  Offline TA/TO
# 117101                    1                 10   BB     GBR  Offline TA/TO
# 117102                    1                 14   BB     IRL         Direct
# 117103                    1                 14   HB     DEU  Offline TA/TO
# 117104                    1                 14   HB     GBR  Offline TA/TO
#
#        DISTRIBUTION_CHANNEL  PREVIOUS_CANCELLATIONS  \
# 0                     TA/TO                       1
# 1                     TA/TO                       1
# 2                     TA/TO                       1
# 3                     TA/TO                       1
# 4                     TA/TO                       1
# ...                     ...                     ...
# 117100                TA/TO                       0
# 117101                TA/TO                       0
# 117102               Direct                       0
# 117103                TA/TO                       0
# 117104                TA/TO                       0
#
#         PREVIOUS_BOOKINGS_NOT_CANCELED RESERVED_ROOM_TYPE ASSIGNED_ROOM_TYPE  \
# 0                                    0                  A                  A
# 1                                    0                  A                  A
# 2                                    0                  A                  A
# 3                                    0                  A                  A
# 4                                    0                  A                  A
# ...                                ...                ...                ...
# 117100                               0                  D                  D
# 117101                               0                  A                  A
# 117102                               0                  E                  E
# 117103                               0                  A                  A
# 117104                               0                  D                  D
#
#        DEPOSIT_TYPE  DAYS_IN_WAITING_LIST    CUSTOMER_TYPE     ADR
# 0        No Deposit                     0  Transient.Party   62.80
# 1        No Deposit                     0  Transient.Party   62.80
# 2        No Deposit                     0  Transient.Party   62.80
# 3        No Deposit                     0  Transient.Party   62.80
# 4        No Deposit                     0  Transient.Party   62.80
# ...             ...                   ...              ...     ...
# 117100   No Deposit                     0         Contract   84.80
# 117101   No Deposit                     0        Transient   89.75
# 117102   No Deposit                     0        Transient  153.57
# 117103   No Deposit                     0        Transient   99.06
# 117104   No Deposit                     0         Contract  112.80
#
# [117009 rows x 32 columns]

# %%
import os
from snowflake.snowpark.session import Session
user = os.getenv("user")
warehouse = os.getenv("warehouse")
schema= os.getenv("schema")
database = os.getenv("database")
role =  os.getenv("role")
account =  os.getenv("account")
password= os.getenv("password")

connection_params = dict(user=user, 
                         password=password, 
                         account=account, 
                         warehouse=warehouse, 
                         database=database,
                         schema=schema, 
                         role=role)

session = Session.builder.configs(connection_params).create()

session.sql('use warehouse {};'.format(warehouse)).collect()

session.sql('use database {};'.format(database)).collect()

session.sql('use schema {}.{};'.format(database, schema)).collect()
# Out:
# [Row(status='Statement executed successfully.')]

# %%
data_backup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 117009 entries, 0 to 117104
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   HOTEL                           117009 non-null  object
#  1   IS_CANCELED                     117009 non-null  int64
#  2   LEAD_TIME                       117009 non-null  int64
#  3   ARRIVAL_DATE_YEAR               117009 non-null  int64
#  4   MONTH                           117009 non-null  int64
#  5   ARRIVAL_DATE_WEEK_NUMBER        117009 non-null  UInt32
#  6   ARRIVAL_DATE_DAY_OF_MONTH       117009 non-null  int64
#  7   EXPECTED_ARRIVAL_DATE           117009 non-null  datetime64[ns]
#  8   RESERVATION_STATUS              117009 non-null  object
#  9   RESERVATION_STATUS_DATE         117009 non-null  object
#  10  TOTAL_STAY_NIGHTS               117009 non-null  int64
#  11  TALLY_DAYS                      117009 non-null  float64
#  12  STAYS_IN_WEEKEND_NIGHTS         117009 non-null  int64
#  13  STAYS_IN_WEEK_NIGHTS            117009 non-null  int64
#  14  ADULTS                          117009 non-null  int64
#  15  CHILDREN                        117009 non-null  int64
#  16  BABIES                          117009 non-null  int64
#  17  TOTAL_GUESTS                    117009 non-null  int64
#  18  AVG_ROOMS_PER_NIGHT             117009 non-null  int64
#  19  TOTAL_ROOM_NIGHTS               117009 non-null  int64
#  20  MEAL                            117009 non-null  object
#  21  COUNTRY                         117009 non-null  object
#  22  MARKET_SEGMENT                  117009 non-null  object
#  23  DISTRIBUTION_CHANNEL            117009 non-null  object
#  24  PREVIOUS_CANCELLATIONS          117009 non-null  int64
#  25  PREVIOUS_BOOKINGS_NOT_CANCELED  117009 non-null  int64
#  26  RESERVED_ROOM_TYPE              117009 non-null  object
#  27  ASSIGNED_ROOM_TYPE              117009 non-null  object
#  28  DEPOSIT_TYPE                    117009 non-null  object
#  29  DAYS_IN_WAITING_LIST            117009 non-null  int64
#  30  CUSTOMER_TYPE                   117009 non-null  object
#  31  ADR                             117009 non-null  float64
# dtypes: UInt32(1), datetime64[ns](1), float64(2), int64(17), object(11)
# memory usage: 29.1+ MB

# %%
data_backup["EXPECTED_ARRIVAL_DATE"] = pd.to_datetime(data_backup["EXPECTED_ARRIVAL_DATE"]).dt.strftime("%Y-%m-%d")
data_backup["RESERVATION_STATUS_DATE"]  = pd.to_datetime(data_backup["RESERVATION_STATUS_DATE"]).dt.strftime("%Y-%m-%d")
# Out:
# <ipython-input-45-5b7c02dd0a9d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_backup["EXPECTED_ARRIVAL_DATE"] = pd.to_datetime(data_backup["EXPECTED_ARRIVAL_DATE"]).dt.strftime("%Y-%m-%d")
# <ipython-input-45-5b7c02dd0a9d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_backup["RESERVATION_STATUS_DATE"]  = pd.to_datetime(data_backup["RESERVATION_STATUS_DATE"]).dt.strftime("%Y-%m-%d")

# %%
data_backup.isna().sum()
# Out:
# HOTEL                             0
# IS_CANCELED                       0
# LEAD_TIME                         0
# ARRIVAL_DATE_YEAR                 0
# MONTH                             0
# ARRIVAL_DATE_WEEK_NUMBER          0
# ARRIVAL_DATE_DAY_OF_MONTH         0
# EXPECTED_ARRIVAL_DATE             0
# RESERVATION_STATUS                0
# RESERVATION_STATUS_DATE           0
# TOTAL_STAY_NIGHTS                 0
# TALLY_DAYS                        0
# STAYS_IN_WEEKEND_NIGHTS           0
# STAYS_IN_WEEK_NIGHTS              0
# ADULTS                            0
# CHILDREN                          0
# BABIES                            0
# TOTAL_GUESTS                      0
# AVG_ROOMS_PER_NIGHT               0
# TOTAL_ROOM_NIGHTS                 0
# MEAL                              0
# COUNTRY                           0
# MARKET_SEGMENT                    0
# DISTRIBUTION_CHANNEL              0
# PREVIOUS_CANCELLATIONS            0
# PREVIOUS_BOOKINGS_NOT_CANCELED    0
# RESERVED_ROOM_TYPE                0
# ASSIGNED_ROOM_TYPE                0
# DEPOSIT_TYPE                      0
# DAYS_IN_WAITING_LIST              0
# CUSTOMER_TYPE                     0
# ADR                               0
# dtype: int64

# %%
df_model=session.createDataFrame(
        data_backup.values.tolist(),
        schema=data_backup.columns.tolist())
df_model.write.mode("overwrite").save_as_table("TTH_DB.TTH_REV_OPT_Schema.BOOKINGS")

# %%
session.close()
