# %% [markdown]
# # Importing helper libraries

# %%
# !pip install --upgrade pip
# !pip install "snowflake-connector-python[pandas]" "snowflake-snowpark-python[pandas]" snowflake-snowpark-python==1.9.0 numpy pandas matplotlib scikit-learn xgboost seaborn python-dateutil tqdm holidays faker
# !pip install --upgrade --q snowflake-snowpark-python==1.9.0
# !pip uninstall urllib3 -y
# !pip install urllib3==1.26.15
# !pip install fosforml==1.1.6

# %%
#from fosforio import snowflake
from fosforml import *
from fosforml.constants import MLModelFlavours
from matplotlib import pyplot as plt
import pandas as pd
pd.set_option('display.max_columns', 500)
import seaborn as sns
from sklearn.metrics import mean_absolute_percentage_error
import numpy as np
import warnings; warnings.simplefilter('ignore')
from joblib import dump, load
import requests
from tqdm import tqdm
import time
import calendar

from time import sleep
import configparser
from dateutil.relativedelta import relativedelta
import datetime
from dateutil.easter import easter
from scipy.optimize import minimize_scalar
from scipy.optimize import curve_fit
import holidays, itertools

# %matplotlib inline

# %% [markdown]
# # Reading the data

# %%
from fosforml.model_manager.snowflakesession import get_session
my_session = get_session()

# %%
table_name = 'BOOKINGS_TRANSFORMED'
data = my_session.sql("select * from {}".format(table_name))
data = data.to_pandas()
data
# Out:
#                HOTEL  IS_CANCELED  LEAD_TIME  ARRIVAL_DATE_YEAR  MONTH  \
# 0         City Hotel            0        226               2023      8
# 1       Resort Hotel            1        210               2024      3
# 2         City Hotel            1        127               2023      9
# 3       Resort Hotel            0         93               2023      8
# 4       Resort Hotel            0         18               2023      9
# ...              ...          ...        ...                ...    ...
# 109613    City Hotel            0         81               2023      8
# 109614    City Hotel            0         18               2023      8
# 109615    City Hotel            0         47               2023      8
# 109616    City Hotel            1         72               2023     10
# 109617  Resort Hotel            0        149               2023      8
#
#         ARRIVAL_DATE_WEEK_NUMBER  ARRIVAL_DATE_DAY_OF_MONTH  \
# 0                             35                         29
# 1                              9                          3
# 2                             37                         12
# 3                             34                         27
# 4                             35                          1
# ...                          ...                        ...
# 109613                        35                         30
# 109614                        35                         30
# 109615                        35                         31
# 109616                        42                         19
# 109617                        34                         26
#
#        EXPECTED_ARRIVAL_DATE RESERVATION_STATUS RESERVATION_STATUS_DATE  \
# 0                 2023-08-29          Check.Out              2023-01-15
# 1                 2024-03-03           Canceled              2023-08-06
# 2                 2023-09-12           Canceled              2023-05-08
# 3                 2023-08-27          Check.Out              2023-05-26
# 4                 2023-09-01          Check.Out              2023-08-14
# ...                      ...                ...                     ...
# 109613            2023-08-30          Check.Out              2023-06-10
# 109614            2023-08-30          Check.Out              2023-08-12
# 109615            2023-08-31          Check.Out              2023-07-15
# 109616            2023-10-19           Canceled              2023-08-08
# 109617            2023-08-26          Check.Out              2023-03-30
#
#         TOTAL_STAY_NIGHTS  TALLY_DAYS  STAYS_IN_WEEKEND_NIGHTS  \
# 0                       4       4.000                        2
# 1                       7       0.183                        2
# 2                       3       0.100                        2
# 3                       6       6.000                        2
# 4                       1       1.000                        0
# ...                   ...         ...                      ...
# 109613                  3       3.000                        2
# 109614                  3       3.000                        2
# 109615                  2       2.000                        1
# 109616                  4       0.470                        1
# 109617                  7       7.000                        2
#
#         STAYS_IN_WEEK_NIGHTS  ADULTS  CHILDREN  BABIES  TOTAL_GUESTS  \
# 0                          2       2         0       0             2
# 1                          5       2         0       0             2
# 2                          1       2         0       0             2
# 3                          4       2         0       0             2
# 4                          1       2         0       0             2
# ...                      ...     ...       ...     ...           ...
# 109613                     1       2         0       0             2
# 109614                     1       2         0       0             2
# 109615                     1       2         0       0             2
# 109616                     3       2         0       0             2
# 109617                     5       2         0       0             2
#
#         AVG_ROOMS_PER_NIGHT  TOTAL_ROOM_NIGHTS MEAL COUNTRY MARKET_SEGMENT  \
# 0                         1                  4   BB     FRA  Offline TA/TO
# 1                         1                  7   HB     PRT  Offline TA/TO
# 2                         1                  3   SC     BRA      Online TA
# 3                         1                  6   HB     AUT      Online TA
# 4                         1                  1   BB     ESP      Online TA
# ...                     ...                ...  ...     ...            ...
# 109613                    1                  3   BB     IRL         Direct
# 109614                    1                  3   SC     BEL      Online TA
# 109615                    1                  2   BB     PRT         Direct
# 109616                    1                  4   SC     FRA      Online TA
# 109617                    1                  7   BB     GBR      Online TA
#
#        DISTRIBUTION_CHANNEL  PREVIOUS_CANCELLATIONS  \
# 0                     TA/TO                       0
# 1                     TA/TO                       0
# 2                     TA/TO                       0
# 3                     TA/TO                       0
# 4                     TA/TO                       0
# ...                     ...                     ...
# 109613               Direct                       0
# 109614                  GDS                       0
# 109615               Direct                       0
# 109616                TA/TO                       0
# 109617                TA/TO                       0
#
#         PREVIOUS_BOOKINGS_NOT_CANCELED RESERVED_ROOM_TYPE ASSIGNED_ROOM_TYPE  \
# 0                                    0                  A                  A
# 1                                    0                  E                  E
# 2                                    0                  A                  A
# 3                                    0                  E                  E
# 4                                    0                  E                  E
# ...                                ...                ...                ...
# 109613                               0                  A                  A
# 109614                               0                  E                  E
# 109615                               0                  E                  E
# 109616                               0                  A                  A
# 109617                               0                  A                  A
#
#        DEPOSIT_TYPE  DAYS_IN_WAITING_LIST    CUSTOMER_TYPE     ADR  \
# 0        No Deposit                     0  Transient.Party   70.00
# 1        No Deposit                     0        Transient   90.00
# 2        No Deposit                     0        Transient   79.20
# 3        No Deposit                     0        Transient  102.93
# 4        No Deposit                     0  Transient.Party   80.00
# ...             ...                   ...              ...     ...
# 109613   No Deposit                     0        Transient   79.80
# 109614   No Deposit                     0        Transient  145.00
# 109615   No Deposit                     0        Transient  135.44
# 109616   No Deposit                     0        Transient   74.80
# 109617   No Deposit                     0        Transient   49.94
#
#        ARRIVAL_DATE_TRANSFORMED RESERVATION_STATUS_DATE_TRANSFORMED
# 0                    2023-08-29                          2023-01-15
# 1                    2024-03-03                          2023-08-06
# 2                    2023-09-12                          2023-05-08
# 3                    2023-08-27                          2023-05-26
# 4                    2023-09-01                          2023-08-14
# ...                         ...                                 ...
# 109613               2023-08-30                          2023-06-10
# 109614               2023-08-30                          2023-08-12
# 109615               2023-08-31                          2023-07-15
# 109616               2023-10-19                          2023-08-08
# 109617               2023-08-26                          2023-03-30
#
# [109618 rows x 34 columns]

# %%
data.columns = map(lambda x: str(x).lower(), data.columns)

# %%
def update_values(row):
    if row['hotel'] == 'City Hotel' and row['reserved_room_type'] == 'A':
        return 150
    elif row['hotel'] == 'City Hotel' and row['reserved_room_type'] == 'D':
        return 80
    elif row['hotel'] == 'City Hotel' and row['reserved_room_type'] == 'E':
        return 30
    elif row['hotel'] == 'Resort Hotel' and row['reserved_room_type'] == 'A':
        return 150
    elif row['hotel'] == 'Resort Hotel' and row['reserved_room_type'] == 'D':
        return 75
    elif row['hotel'] == 'Resort Hotel' and row['reserved_room_type'] == 'E':
        return 60
    else:
        pass

# %%
data['room_limit'] = data.apply(update_values, axis=1)

# %%
hotels = data['hotel'].unique()

# %%
from scipy.optimize import curve_fit

# Define the demand curve function
def demand_curve(x, a, b, c, d, max_demand):
    demand = a * np.exp(-b * x) + c
    demand = np.where(x <= max_demand, np.minimum(demand, max_demand), demand)
    return demand + d

# %%
def revenue(price):
    return price * demand_curve(price, a_fit, b_fit,c_fit,d_fit,max_demand)

# %%
from scipy.optimize import brentq

def demand_to_price(num_rooms, a, b, c, d, max_demand):
    def root_func(x):
        return num_rooms - (a * np.exp(-b * x) + c)

    try:
        price = brentq(root_func, 0, 200)  # Adjust the interval bounds as needed
    except ValueError:
        # Fallback to default price if no root is found
        price_range=(0, 200)
        price = np.random.uniform(*price_range)

    return price

# %%
def data_conversion(data):
    import holidays
    hotels = data['hotel'].unique()
    room_types = data['reserved_room_type'].unique()
    expanded_df = pd.DataFrame()
    for _, row in data.iterrows():
        num_stay_dates = row['total_rns']
        try:
            # Create a row for each stay date
            expanded_booking = pd.DataFrame({
                'hotel': row['hotel'],
                'room_type': row['reserved_room_type'], 
                'arrival_date': pd.date_range(start=row['expected_arrival_date'], periods=num_stay_dates),
                'total_rns': 1,
                'adr': row['adr'],
                'room_limit': row['room_limit']
            })

            # Append the stay date information to the new dataframe
            expanded_df = pd.concat([expanded_df, expanded_booking], ignore_index=True)
        except ValueError as e:
            print(f"Error processing booking for {row['hotel']} on {row['expected_arrival_date']} : {num_stay_dates} {e}")
    expanded_df = expanded_df.sort_values('arrival_date')
    expanded_df = expanded_df.reset_index(drop=True)
    expanded_df['adr']= np.round(expanded_df['adr'], 2)
           
    expanded_df['dow'] = expanded_df.arrival_date.dt.strftime('%A')
    expanded_df['month'] = expanded_df.arrival_date.dt.strftime('%B')

    return expanded_df

data['total_rns'] = data['stays_in_week_nights'] + data['stays_in_weekend_nights']

# %%
data = data[(data['is_canceled'] == 0) & (data['reservation_status'] !='No-Show')] 
data = data[(data.market_segment != 'Complementary') ]
data = data[(data.reserved_room_type == 'A') |(data.reserved_room_type == 'D') | (data.reserved_room_type == 'E')]

converted_df = data_conversion(data[['hotel', 'reserved_room_type', 'expected_arrival_date', 'adr', 'room_limit', 'total_rns']])
converted_df
# Out:
#                hotel room_type arrival_date  total_rns     adr  room_limit  \
# 0         City Hotel         A   2022-05-01          1   80.00         150
# 1       Resort Hotel         D   2022-05-01          1  153.00          75
# 2         City Hotel         A   2022-05-01          1  101.50         150
# 3         City Hotel         A   2022-05-01          1   80.00         150
# 4         City Hotel         A   2022-05-01          1  101.50         150
# ...              ...       ...          ...        ...     ...         ...
# 232598  Resort Hotel         E   2024-07-11          1  153.57          60
# 232599  Resort Hotel         A   2024-07-12          1   99.06         150
# 232600  Resort Hotel         D   2024-07-12          1  112.80          75
# 232601  Resort Hotel         A   2024-07-13          1   99.06         150
# 232602  Resort Hotel         D   2024-07-13          1  112.80          75
#
#              dow month
# 0         Sunday   May
# 1         Sunday   May
# 2         Sunday   May
# 3         Sunday   May
# 4         Sunday   May
# ...          ...   ...
# 232598  Thursday  July
# 232599    Friday  July
# 232600    Friday  July
# 232601  Saturday  July
# 232602  Saturday  July
#
# [232603 rows x 8 columns]

# %%
converted_df["arrival_date"] = pd.to_datetime(converted_df["arrival_date"]).dt.strftime("%Y-%m-%d %H:%M:%S")

# %%
# df_model=my_session.createDataFrame(
#         converted_df.values.tolist(),
#         schema=converted_df.columns.tolist())
# df_model.write.mode("overwrite").save_as_table("TTH_DB.TTH_REV_OPT_Schema.CONVERTED_PRICING_DATA")


my_session.write_pandas(converted_df, "TTH_DB.TTH_REV_OPT_Schema.CONVERTED_PRICING_DATA", auto_create_table=True, overwrite=True)

# %%
my_session.sql("DROP PROCEDURE IF EXISTS CREATE_PRICING_MODEL(String)").collect()
# Out:
# [Row(status='Drop statement executed successfully (CREATE_PRICING_MODEL already dropped).')]

# %%
my_session.sql('''
CREATE OR REPLACE PROCEDURE create_pricing_model(table_name STRING)
RETURNS STRING
LANGUAGE PYTHON
RUNTIME_VERSION = '3.8'
PACKAGES = ('snowflake-snowpark-python', 'pandas', 'numpy', 'scipy')
HANDLER = 'create_pricing_model'
AS
$$
from snowflake.snowpark.session import Session
from snowflake.snowpark.functions import col
import pandas as pd
import numpy as np
from scipy.optimize import minimize_scalar, curve_fit, brentq
import itertools
def create_pricing_model(session, table_name=None):


    # Define functions
    def revenue(price):
        return price * demand_curve(price, a_fit, b_fit, c_fit, d_fit, max_demand)

    def demand_curve(x, a, b, c, d, max_demand):
        demand = a * np.exp(-b * x) + c
        demand = np.where(x <= max_demand, np.minimum(demand, max_demand), demand)
        return demand + d

    def demand_to_price(num_rooms, a, b, c, d, max_demand):
        def root_func(x):
            return num_rooms - (a * np.exp(-b * x) + c)

        try:
            price = brentq(root_func, 0, 200)
        except ValueError:
            price_range = (0, 200)
            price = np.random.uniform(*price_range)

        return price

    # Retrieve data from Snowflake table
    expanded_df = session.table([table_name]).to_pandas()
    expanded_df.columns = map(lambda x: str(x).lower(), expanded_df.columns)

    results = pd.DataFrame(columns=['month', 'hotel', 'room_limit', 'room_type', 'dow', 'optimal_rate', 'expected_rn', 'expected_rev', 'optimal_rate_lim_inv'])
    hotel_types = ['Resort Hotel', 'City Hotel']
    room_types = ['A', 'D', 'E']
    daily_rns = expanded_df.groupby(['arrival_date', 'dow', 'month', 'hotel', 'room_type']).agg({'room_limit': 'mean', 'total_rns': 'sum'}).reset_index()
    daily_rns = daily_rns.groupby(['dow', 'month', 'hotel', 'room_type']).agg({'room_limit': 'mean', 'total_rns': ['sum', 'mean', 'median']}).reset_index()
    daily_rns.columns = ['_'.join(col) for col in daily_rns.columns]
    adr_frequency = expanded_df.groupby(['dow', 'month', 'adr', 'hotel', 'room_type']).agg({'room_limit': 'mean', 'total_rns': 'sum'})
    adr_frequency.reset_index(inplace=True)
    merged_df = pd.merge(adr_frequency, daily_rns, how='left', left_on=['dow', 'month', 'hotel', 'room_type'], right_on=['dow_', 'month_', 'hotel_', 'room_type_'], suffixes=('_act', '_tot'))
    merged_df = merged_df.drop(['dow_', 'month_'], axis=1)
    merged_df['probability'] = merged_df['total_rns'] / merged_df['total_rns_sum']
    merged_df['expected_rns'] = merged_df['probability'] * merged_df['total_rns_median']
    merged_df = merged_df.sort_values(by=['dow', 'month', 'adr'], ascending=[True, True, False])
    merged_df['expected_demand'] = merged_df.groupby(['dow', 'month'])['expected_rns'].cumsum()
    merged_df['expected_rev'] = merged_df['adr'] * merged_df['expected_demand']
    results = pd.DataFrame(columns=['month', 'hotel', 'room_limit', 'room_type', 'dow', 'optimal_rate', 'expected_rn', 'expected_rev', 'optimal_rate_lim_inv'])
    months = merged_df.month.unique()
    dow = merged_df.dow.unique()

    for hotel in hotel_types:
        for room_type in room_types:
            for month in months:
                for day in dow:
                    data_subset = merged_df[(merged_df['dow'] == day) & (merged_df['hotel'] == hotel) & (merged_df['room_type'] == room_type) & (merged_df['month'] == month)].reset_index()
                    if data_subset.empty:
                        continue

                    mean = data_subset['adr'].mean()
                    std_dev = data_subset['adr'].std()
                    data_subset['z_scores'] = np.abs((data_subset['adr'] - mean) / std_dev)
                    data_subset = data_subset[data_subset['z_scores'] <= 2]

                    x_data = data_subset['adr'].values
                    y_data = data_subset['expected_demand'].values

                    try:
                        initial_guess = [1, 0.01, 1, 1, data_subset['total_rns_median'].values[0]]
                        bounds = ([0, 0, 0, 0, 0], [np.inf, np.inf, np.inf, np.inf, np.inf])
                        maxfev = 10000
                        params, _ = curve_fit(demand_curve, x_data, y_data, bounds=bounds, p0=initial_guess, maxfev=maxfev)
                    except RuntimeError as e:
                        print(f"Error fitting demand curve for {hotel}, {room_type}, {month}, {day}: {e}")
                        continue

                    a_fit, b_fit, c_fit, d_fit, max_demand = params

                    def revenue(price):
                        return price * demand_curve(price, a_fit, b_fit, c_fit, d_fit, max_demand)

                    objective = lambda price: -revenue(price)
                    optimize = minimize_scalar(objective, bounds=(45, 200), method='bounded')
                    optimal_price = optimize.x
                    max_revenue = -optimize.fun
                    expected_rns = demand_curve(optimal_price, a_fit, b_fit, c_fit, d_fit, max_demand)
                    optimal_rate_lim_inv = demand_to_price(data_subset['room_limit'].mean(), a_fit, b_fit, c_fit, d_fit, max_demand)

                    new_row = pd.DataFrame({'hotel': hotel, 'room_type': room_type, 'room_limit': data_subset['room_limit'].mean(), 'month': month, 'dow': day, 'optimal_rate': optimal_price, 'expected_rev': max_revenue, 'expected_rn': expected_rns, 'optimal_rate_lim_inv': optimal_rate_lim_inv}, index=[0])
                    results = pd.concat([results, new_row], ignore_index=True)

    results['optimal_rate'] = results['optimal_rate'].round()
    results['optimal_rate_lim_inv'] = results['optimal_rate_lim_inv'].round()
    results['expected_rn'] = results['expected_rn'].round().astype(int)
    results['expected_rev'] = results['expected_rev'].round()
    combinations = list(itertools.product(hotel_types, room_types))
    combinations_df = pd.DataFrame(combinations, columns=['hotel', 'room_type'])
    month_dict = {month: index for index, month in enumerate(pd.date_range('2020-01-01', periods=12, freq='M').strftime('%B'), 1)}

    new_data = pd.DataFrame()

    for year in range(2020, 2024):
        for month in month_dict.values():
            start_date = pd.to_datetime(f'{year}-{month}-01').replace(day=1)
            end_date = pd.to_datetime(f'{year}-{month}-01').replace(day=1) + pd.offsets.MonthEnd(0)
            date_range = pd.date_range(start_date, end_date, freq='D')
            df = pd.DataFrame(date_range, columns=['arrival_date'])
            df['dow'] = df['arrival_date'].dt.day_name()
            df['month'] = df['arrival_date'].dt.month_name()

            result_df = df.assign(key=1).merge(combinations_df.assign(key=1), on='key').drop('key', axis=1)
            new_data = pd.concat([new_data, result_df], ignore_index=True)

    final_data = pd.merge(new_data, results, how='left', on=['dow', 'hotel', 'room_type', 'month'])
    final_data.replace([np.inf, -np.inf], np.nan, inplace=True)
    final_data = final_data.dropna()
    final_data['room_limit'] = final_data['room_limit'].astype(int)
    final_data['arrival_date'] = pd.to_datetime(final_data['arrival_date']).dt.strftime("%Y-%m-%d %H:%M:%S")
    df_model = session.createDataFrame(final_data.values.tolist(), schema=final_data.columns.tolist())
    df_model.write.mode("overwrite").save_as_table("TTH_DB.TTH_REV_OPT_Schema.PROCESSED_PRICING_DATA")

    return "Data processed and dumped back to Snowflake"
$$
''').collect()
# Out:
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 my_session.sql('''
#       2 CREATE OR REPLACE PROCEDURE create_pricing_model(table_name STRING)
#       3 RETURNS STRING
#       4 LANGUAGE PYTHON
#       5 RUNTIME_VERSION = '3.8'
#       6 PACKAGES = ('snowflake-snowpark-python', 'pandas', 'numpy', 'scipy')
#       7 HANDLER = 'create_pricing_model'
#       8 AS
#       9 $$
#      10 from snowflake.snowpark.session import Session
#      11 from snowflake.snowpark.functions import col
#      12 import pandas as pd
#      13 import numpy as np
#      14 from scipy.optimize import minimize_scalar, curve_fit, brentq
#      15 import itertools
#      16 def create_pricing_model(session, table_name=None):
#      17
#      18
#      19     # Define functions
#      20     def revenue(price):
#      21         return price * demand_curve(price, a_fit, b_fit, c_fit, d_fit, max_demand)
#      22
#      23     def demand_curve(x, a, b, c, d, max_demand):
#      24         demand = a * np.exp(-b * x) + c
#      25         demand = np.where(x <= max_demand, np.minimum(demand, max_demand), demand)
#      26         return demand + d
#      27
#      28     def demand_to_price(num_rooms, a, b, c, d, max_demand):
#      29         def root_func(x):
#      30             return num_rooms - (a * np.exp(-b * x) + c)
#      31
#      32         try:
#      33             price = brentq(root_func, 0, 200)
#      34         except ValueError:
#      35             price_range = (0, 200)
#      36             price = np.random.uniform(*price_range)
#      37
#      38         return price
#      39
#      40     # Retrieve data from Snowflake table
#      41     expanded_df = session.table([table_name]).to_pandas()
#      42     expanded_df.columns = map(lambda x: str(x).lower(), expanded_df.columns)
#      43
#      44     results = pd.DataFrame(columns=['month', 'hotel', 'room_limit', 'room_type', 'dow', 'optimal_rate', 'expected_rn', 'expected_rev', 'optimal_rate_lim_inv'])
#      45     hotel_types = ['Resort Hotel', 'City Hotel']
#      46     room_types = ['A', 'D', 'E']
#      47     daily_rns = expanded_df.groupby(['arrival_date', 'dow', 'month', 'hotel', 'room_type']).agg({'room_limit': 'mean', 'total_rns': 'sum'}).reset_index()
#      48     daily_rns = daily_rns.groupby(['dow', 'month', 'hotel', 'room_type']).agg({'room_limit': 'mean', 'total_rns': ['sum', 'mean', 'median']}).reset_index()
#      49     daily_rns.columns = ['_'.join(col) for col in daily_rns.columns]
#      50     adr_frequency = expanded_df.groupby(['dow', 'month', 'adr', 'hotel', 'room_type']).agg({'room_limit': 'mean', 'total_rns': 'sum'})
#      51     adr_frequency.reset_index(inplace=True)
#      52     merged_df = pd.merge(adr_frequency, daily_rns, how='left', left_on=['dow', 'month', 'hotel', 'room_type'], right_on=['dow_', 'month_', 'hotel_', 'room_type_'], suffixes=('_act', '_tot'))
#      53     merged_df = merged_df.drop(['dow_', 'month_'], axis=1)
#      54     merged_df['probability'] = merged_df['total_rns'] / merged_df['total_rns_sum']
#      55     merged_df['expected_rns'] = merged_df['probability'] * merged_df['total_rns_median']
#      56     merged_df = merged_df.sort_values(by=['dow', 'month', 'adr'], ascending=[True, True, False])
#      57     merged_df['expected_demand'] = merged_df.groupby(['dow', 'month'])['expected_rns'].cumsum()
#      58     merged_df['expected_rev'] = merged_df['adr'] * merged_df['expected_demand']
#      59     results = pd.DataFrame(columns=['month', 'hotel', 'room_limit', 'room_type', 'dow', 'optimal_rate', 'expected_rn', 'expected_rev', 'optimal_rate_lim_inv'])
#      60     months = merged_df.month.unique()
#      61     dow = merged_df.dow.unique()
#      62
#      63     for hotel in hotel_types:
#      64         for room_type in room_types:
#      65             for month in months:
#      66                 for day in dow:
#      67                     data_subset = merged_df[(merged_df['dow'] == day) & (merged_df['hotel'] == hotel) & (merged_df['room_type'] == room_type) & (merged_df['month'] == month)].reset_index()
#      68                     if data_subset.empty:
#      69                         continue
#      70
#      71                     mean = data_subset['adr'].mean()
#      72                     std_dev = data_subset['adr'].std()
#      73                     data_subset['z_scores'] = np.abs((data_subset['adr'] - mean) / std_dev)
#      74                     data_subset = data_subset[data_subset['z_scores'] <= 2]
#      75
#      76                     x_data = data_subset['adr'].values
#      77                     y_data = data_subset['expected_demand'].values
#      78
#      79                     try:
#      80                         initial_guess = [1, 0.01, 1, 1, data_subset['total_rns_median'].values[0]]
#      81                         bounds = ([0, 0, 0, 0, 0], [np.inf, np.inf, np.inf, np.inf, np.inf])
#      82                         maxfev = 10000
#      83                         params, _ = curve_fit(demand_curve, x_data, y_data, bounds=bounds, p0=initial_guess, maxfev=maxfev)
#      84                     except RuntimeError as e:
#      85                         print(f"Error fitting demand curve for {hotel}, {room_type}, {month}, {day}: {e}")
#      86                         continue
#      87
#      88                     a_fit, b_fit, c_fit, d_fit, max_demand = params
#      89
#      90                     def revenue(price):
#      91                         return price * demand_curve(price, a_fit, b_fit, c_fit, d_fit, max_demand)
#      92
#      93                     objective = lambda price: -revenue(price)
#      94                     optimize = minimize_scalar(objective, bounds=(45, 200), method='bounded')
#      95                     optimal_price = optimize.x
#      96                     max_revenue = -optimize.fun
#      97                     expected_rns = demand_curve(optimal_price, a_fit, b_fit, c_fit, d_fit, max_demand)
#      98                     optimal_rate_lim_inv = demand_to_price(data_subset['room_limit'].mean(), a_fit, b_fit, c_fit, d_fit, max_demand)
#      99
#     100                     new_row = pd.DataFrame({'hotel': hotel, 'room_type': room_type, 'room_limit': data_subset['room_limit'].mean(), 'month': month, 'dow': day, 'optimal_rate': optimal_price, 'expected_rev': max_revenue, 'expected_rn': expected_rns, 'optimal_rate_lim_inv': optimal_rate_lim_inv}, index=[0])
#     101                     results = pd.concat([results, new_row], ignore_index=True)
#     102
#     103     results['optimal_rate'] = results['optimal_rate'].round()
#     104     results['optimal_rate_lim_inv'] = results['optimal_rate_lim_inv'].round()
#     105     results['expected_rn'] = results['expected_rn'].round().astype(int)
#     106     results['expected_rev'] = results['expected_rev'].round()
#     107     combinations = list(itertools.product(hotel_types, room_types))
#     108     combinations_df = pd.DataFrame(combinations, columns=['hotel', 'room_type'])
#     109     month_dict = {month: index for index, month in enumerate(pd.date_range('2020-01-01', periods=12, freq='M').strftime('%B'), 1)}
#     110
#     111     new_data = pd.DataFrame()
#     112
#     113     for year in range(2020, 2024):
#     114         for month in month_dict.values():
#     115             start_date = pd.to_datetime(f'{year}-{month}-01').replace(day=1)
#     116             end_date = pd.to_datetime(f'{year}-{month}-01').replace(day=1) + pd.offsets.MonthEnd(0)
#     117             date_range = pd.date_range(start_date, end_date, freq='D')
#     118             df = pd.DataFrame(date_range, columns=['arrival_date'])
#     119             df['dow'] = df['arrival_date'].dt.day_name()
#     120             df['month'] = df['arrival_date'].dt.month_name()
#     121
#     122             result_df = df.assign(key=1).merge(combinations_df.assign(key=1), on='key').drop('key', axis=1)
#     123             new_data = pd.concat([new_data, result_df], ignore_index=True)
#     124
#     125     final_data = pd.merge(new_data, results, how='left', on=['dow', 'hotel', 'room_type', 'month'])
#     126     final_data.replace([np.inf, -np.inf], np.nan, inplace=True)
#     127     final_data = final_data.dropna()
#     128     final_data['room_limit'] = final_data['room_limit'].astype(int)
#     129     final_data['arrival_date'] = pd.to_datetime(final_data['arrival_date']).dt.strftime("%Y-%m-%d %H:%M:%S")
#     130     df_model = session.createDataFrame(final_data.values.tolist(), schema=final_data.columns.tolist())
#     131     df_model.write.mode("overwrite").save_as_table("TTH_DB.TTH_REV_OPT_Schema.PROCESSED_PRICING_DATA")
#     132
#     133     return "Data processed and dumped back to Snowflake"
#     134 $$
#     135 ''').collect()
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/telemetry.py:151, in df_collect_api_telemetry.<locals>.wrap(*args, **kwargs)
#     148 @functools.wraps(func)
#     149 def wrap(*args, **kwargs):
#     150     with args[0]._session.query_history() as query_history:
# --> 151         result = func(*args, **kwargs)
#     152     plan = args[0]._select_statement or args[0]._plan
#     153     api_calls = [
#     154         *plan.api_calls,
#     155         {TelemetryField.NAME.value: f"DataFrame.{func.__name__}"},
#     156     ]
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/dataframe.py:600, in DataFrame.collect(self, statement_params, block, log_on_exception, case_sensitive)
#     585 """Executes the query representing this DataFrame and returns the result as a
#     586 list of :class:`Row` objects.
#     587
#    (...)
#     597     :meth:`collect_nowait()`
#     598 """
#     599 with open_telemetry_context_manager(self.collect, self):
# --> 600     return self._internal_collect_with_tag_no_telemetry(
#     601         statement_params=statement_params,
#     602         block=block,
#     603         log_on_exception=log_on_exception,
#     604         case_sensitive=case_sensitive,
#     605     )
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/dataframe.py:648, in DataFrame._internal_collect_with_tag_no_telemetry(self, statement_params, block, data_type, log_on_exception, case_sensitive)
#     636 def _internal_collect_with_tag_no_telemetry(
#     637     self,
#     638     *,
#    (...)
#     646     # we should always call this method instead of collect(), to make sure the
#     647     # query tag is set properly.
# --> 648     return self._session._conn.execute(
#     649         self._plan,
#     650         block=block,
#     651         data_type=data_type,
#     652         _statement_params=create_or_update_statement_params_with_query_tag(
#     653             statement_params or self._statement_params,
#     654             self._session.query_tag,
#     655             SKIP_LEVELS_THREE,
#     656         ),
#     657         log_on_exception=log_on_exception,
#     658         case_sensitive=case_sensitive,
#     659     )
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/server_connection.py:526, in ServerConnection.execute(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, **kwargs)
#     516 if (
#     517     is_in_stored_procedure()
#     518     and not block
#    (...)
#     521     )
#     522 ):  # pragma: no cover
#     523     raise NotImplementedError(
#     524         "Async query is not supported in stored procedure yet"
#     525     )
# --> 526 result_set, result_meta = self.get_result_set(
#     527     plan,
#     528     to_pandas,
#     529     to_iter,
#     530     **kwargs,
#     531     block=block,
#     532     data_type=data_type,
#     533     log_on_exception=log_on_exception,
#     534     case_sensitive=case_sensitive,
#     535 )
#     536 if not block:
#     537     return result_set
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:206, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     202 else:
#     203     ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     204         e
#     205     )
# --> 206     raise ne.with_traceback(tb) from None
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:137, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     135 def wrap(*args, **kwargs):
#     136     try:
# --> 137         return func(*args, **kwargs)
#     138     except snowflake.connector.errors.ProgrammingError as e:
#     139         query = getattr(e, "query", None)
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/server_connection.py:630, in ServerConnection.get_result_set(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, ignore_results, **kwargs)
#     628 for holder, id_ in placeholders.items():
#     629     final_query = final_query.replace(holder, id_)
# --> 630 result = self.run_query(
#     631     final_query,
#     632     to_pandas,
#     633     to_iter and (i == len(main_queries) - 1),
#     634     is_ddl_on_temp_object=query.is_ddl_on_temp_object,
#     635     block=not is_last,
#     636     data_type=data_type,
#     637     async_job_plan=plan,
#     638     log_on_exception=log_on_exception,
#     639     case_sensitive=case_sensitive,
#     640     params=query.params,
#     641     ignore_results=ignore_results,
#     642     **kwargs,
#     643 )
#     644 placeholders[query.query_id_place_holder] = (
#     645     result["sfqid"] if not is_last else result.query_id
#     646 )
#     647 result_meta = get_new_description(self._cursor)
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/server_connection.py:125, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     121     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     122         ex.cause
#     123     )
#     124 except Exception as ex:
# --> 125     raise ex
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/server_connection.py:119, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     117     raise SnowparkClientExceptionMessages.SERVER_SESSION_HAS_BEEN_CLOSED()
#     118 try:
# --> 119     return func(*args, **kwargs)
#     120 except ReauthenticationRequest as ex:
#     121     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     122         ex.cause
#     123     )
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/server_connection.py:433, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, ignore_results, **kwargs)
#     431         query_id_log = f" [queryID: {ex.sfqid}]" if hasattr(ex, "sfqid") else ""
#     432         logger.error(f"Failed to execute query{query_id_log} {query}\n{ex}")
# --> 433     raise ex
#     435 # fetch_pandas_all/batches() only works for SELECT statements
#     436 # We call fetchall() if fetch_pandas_all/batches() fails,
#     437 # because when the query plan has multiple queries, it will
#     438 # have non-select statements, and it shouldn't fail if the user
#     439 # calls to_pandas() to execute the query.
#     440 if block:
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/server_connection.py:418, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, ignore_results, **kwargs)
#     416     kwargs["_statement_params"]["SNOWPARK_SKIP_TXN_COMMIT_IN_DDL"] = True
#     417 if block:
# --> 418     results_cursor = self.execute_and_notify_query_listener(
#     419         query, params=params, **kwargs
#     420     )
#     421     logger.debug(f"Execute query [queryID: {results_cursor.sfqid}] {query}")
#     422 else:
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/server_connection.py:369, in ServerConnection.execute_and_notify_query_listener(self, query, **kwargs)
#     366 def execute_and_notify_query_listener(
#     367     self, query: str, **kwargs: Any
#     368 ) -> SnowflakeCursor:
# --> 369     results_cursor = self._cursor.execute(query, **kwargs)
#     370     self.notify_query_listeners(
#     371         QueryRecord(results_cursor.sfqid, results_cursor.query)
#     372     )
#     373     return results_cursor
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/cursor.py:1087, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements, _dataframe_ast)
#    1083     is_integrity_error = (
#    1084         code == "100072"
#    1085     )  # NULL result in a non-nullable column
#    1086     error_class = IntegrityError if is_integrity_error else ProgrammingError
# -> 1087     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#    1088 return self
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/errors.py:284, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     261 @staticmethod
#     262 def errorhandler_wrapper(
#     263     connection: SnowflakeConnection | None,
#    (...)
#     266     error_value: dict[str, Any],
#     267 ) -> None:
#     268     """Error handler wrapper that calls the errorhandler method.
#     269
#     270     Args:
#    (...)
#     281         exception to the first handler in that order.
#     282     """
# --> 284     handed_over = Error.hand_to_other_handler(
#     285         connection,
#     286         cursor,
#     287         error_class,
#     288         error_value,
#     289     )
#     290     if not handed_over:
#     291         raise Error.errorhandler_make_exception(
#     292             error_class,
#     293             error_value,
#     294         )
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/errors.py:339, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     337 if cursor is not None:
#     338     cursor.messages.append((error_class, error_value))
# --> 339     cursor.errorhandler(connection, cursor, error_class, error_value)
#     340     return True
#     341 elif connection is not None:
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/errors.py:215, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     213 errno = error_value.get("errno")
#     214 done_format_msg = error_value.get("done_format_msg")
# --> 215 raise error_class(
#     216     msg=error_value.get("msg"),
#     217     errno=None if errno is None else int(errno),
#     218     sqlstate=error_value.get("sqlstate"),
#     219     sfqid=error_value.get("sfqid"),
#     220     query=error_value.get("query"),
#     221     done_format_msg=(
#     222         None if done_format_msg is None else bool(done_format_msg)
#     223     ),
#     224     connection=connection,
#     225     cursor=cursor,
#     226 )
#
# SnowparkSQLException: (1304): 01b6c24f-070e-58e8-0072-f303104921fe: 003041 (42710): SQL compilation error:
# Procedure 'CREATE_PRICING_MODEL(TABLE_NAME VARCHAR):VARCHAR(16777216)' already exists, but current role has no privileges on it. If this is unexpected and you cannot resolve this problem, contact your system administrator. ACCOUNTADMIN role may be required to manage the privileges on the object.

# %%
result = my_session.call("create_pricing_model", "TTH_DB.TTH_REV_OPT_Schema.CONVERTED_PRICING_DATA")
result
