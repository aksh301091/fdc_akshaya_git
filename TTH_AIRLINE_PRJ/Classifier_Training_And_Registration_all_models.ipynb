# %% [markdown]
# # **Flight Delay Prediction using Scikit-Learn Pipeline**
#
# ## **Overview**
# This project demonstrates how to build a **machine learning pipeline** using scikit-learn to predict flight delays. The pipeline integrates data preprocessing with model training, ensuring efficient handling of both numerical and categorical data.
#
# ---
#
# ## **Objectives**
# - Preprocess numerical and categorical data using `ColumnTransformer`.
# - Automate the machine learning workflow using `Pipeline`.
# - Train a **Random Forest Classifier** to predict flight delays.
# - Optimize the model using **GridSearchCV** for hyperparameter tuning.
#
# ---
#
# ## **Data Overview**
# - **Dataset**: Contains flight details such as:
#   - **Year**, **Month**, **Day**
#   - **Airline code**, **Origin airport code**, **Destination airport code**
#   - **Departure delay** (target: delayed or not)
#
# - **Target Variable**:
#   - `1` if the flight was delayed
#   - `0` if the flight was on time
#
# ---
#
# ## **Steps Involved**
#
# ### 1. **Data Loading and Exploration**
# - Load the flight dataset and inspect its structure and missing values.
#
# ### 2. **Feature Engineering**
# - **Numerical Features**:
#   - `YEAR`, `MONTH`, `DAY`
# - **Categorical Features**:
#   - `AIRLINE__CODE`, `ORIGIN_AIRPORT_CODE`, `DESTINATION_AIRPORT_CODE`
#
# ### 3. **Preprocessing with `ColumnTransformer`**
# - **Numerical Data**:
#   - Impute missing values with the **mean**.
#   - Standardize values using **`StandardScaler`**.
#
# - **Categorical Data**:
#   - Impute missing values with `'missing'`.
#   - Encode using **`OneHotEncoder`**.
#
# ### 4. **Pipeline Setup**
# - Use a **scikit-learn Pipeline** to link preprocessing and model training.
# - Integrate a **Random Forest Classifier** within the pipeline.
#
# ### 5. **Model Training and Evaluation**
# - Split the data into **train (70%)** and **test (30%)** sets.
# - Evaluate the model using a **classification report** with metrics like:
#   - **Precision**, **Recall**, **F1-score**
#
# ### 6. **Hyperparameter Tuning with GridSearchCV**
# - Tune hyperparameters of the Random Forest model:
#   - Number of estimators (`n_estimators`)
#   - Maximum tree depth (`max_depth`)
#
# ### 7. **Model Persistence**
# - Save the trained model using **`joblib`** for later use.
#
# ---
#
# ## **Technologies Used**
# - **Python**: Programming language
# - **Pandas**: Data manipulation and cleaning
# - **Scikit-Learn**: Machine learning, preprocessing, and model evaluation
# - **Joblib**: Model persistence
# - **Jupyter Notebook**: Interactive development environment
#
# ---
#
# ## **Expected Output**
# - A **trained Random Forest model** to predict flight delays.
# - **Performance metrics** (accuracy, precision, recall) from the classification report.
# - A **saved model** (`flight_delay_classifier.pkl`) for deployment.
#
# ---
#
# ## **Conclusion**
# This project demonstrates how to create an automated **machine learning workflow** using scikit-learn’s `Pipeline` and `ColumnTransformer`. The streamlined preprocessing ensures consistency during both training and testing. With **hyperparameter tuning**, the model's performance is further optimized, making it reliable for real-world flight delay predictions.

# %% [markdown]
# # Upgrade pip and install all required packages

# %%
# !pip install --upgrade pip

# Install Snowflake connectors, pandas integration, and essential libraries
# !pip install "snowflake-connector-python[pandas]" \
             snowflake-snowpark-python==1.12.0,<2,>=1.11.1 \
             python-dateutil tqdm holidays faker
# !pip install numpy pandas matplotlib scikit-learn xgboost seaborn \

# Ensure Snowpark Python is up-to-date
# !pip install --upgrade -q snowflake-snowpark-python==1.12.0,<2,>=1.11.1


# Fix potential urllib3 version conflicts
# !pip uninstall urllib3 -y
# !pip install urllib3==1.26.15

# Additional installations for your project
# !pip install fosforml==1.1.6
# !pip install python-scipy
# !pip install cloudpickle==2.2.1
# !pip install basemap

# %% [markdown]
# # Importing necessary libraries and settings

# %%
# Standard libraries for date and warnings
import datetime
import warnings

# Scientific and Data Manipulation Libraries
import scipy
import pandas as pd
import numpy as np

# Data Visualization Libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb

# Sklearn Modules for Data Preprocessing, Modeling, and Evaluation
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder  # Encoding categorical variables
from sklearn.preprocessing import StandardScaler  # Scaling numerical data
from sklearn.tree import DecisionTreeClassifier  # Decision Tree model
from sklearn.metrics import roc_auc_score, classification_report  # Evaluation metrics

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression

import configparser
from dateutil.relativedelta import relativedelta
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
# %matplotlib inline

# Configuring display options and warning filters
pd.options.display.max_columns = 50
warnings.filterwarnings("ignore")

# Custom FosforML package for Snowflake session and model registration
from fosforml.model_manager.snowflakesession import get_session
from fosforml import register_model
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
# Set Matplotlib's default font family to 'DeJavu Serif' to ensure a consistent font style across plots
plt.rcParams['font.family'] = 'DeJavu Serif'

# %% [markdown]
# # Establishing a Snowflake session

# %%
my_session = get_session()

# Defining the table name to fetch data from
# table_name = 'FLIGHTS'  # Initial option for table
table_name = 'FLIGHTS_FULL'  # Final table to be used

# Querying the data from the specified Snowflake table
sf_df = my_session.sql("SELECT * FROM {}".format(table_name))

# Converting the Snowflake DataFrame to a pandas DataFrame for local processing
df = sf_df.to_pandas()

df
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE__CODE  FLIGHT_NUMBER  \
# 0        2024      4   23            4            AA           1114
# 1        2024      4   23            4            B6            813
# 2        2024      4   23            4            DL           1612
# 3        2024      4   23            4            DL           1642
# 4        2024      4   23            4            EV           4973
# ...       ...    ...  ...          ...           ...            ...
# 5819074  2024      3   24            2            DL           1242
# 5819075  2024      3   24            2            DL           1353
# 5819076  2024      3   24            2            DL           1544
# 5819077  2024      3   24            2            F9           1183
# 5819078  2024      3   24            2            B6           1667
#
#         TAIL_NUMBER ORIGIN_AIRPORT_CODE DESTINATION_AIRPORT_CODE  \
# 0            N3HTAA                 LGA                      DFW
# 1            N775JB                 HPN                      FLL
# 2            N942DL                 ORD                      ATL
# 3            N906AT                 ATL                      CAK
# 4            N931EV                 ATL                      GTR
# ...             ...                 ...                      ...
# 5819074      N949DL                 LGA                      PBI
# 5819075      N904DE                 ATL                      PNS
# 5819076      N937DL                 MSP                      MSN
# 5819077      N933FR                 MDT                      MCO
# 5819078      N283JB                 BOS                      CHS
#
#          SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY  TAXI_OUT  \
# 0                       1529          1542.0             13.0      18.0
# 1                       1529          1520.0             -9.0      15.0
# 2                       1529          1529.0              0.0      11.0
# 3                       1529          1526.0             -3.0      17.0
# 4                       1530          1528.0             -2.0      27.0
# ...                      ...             ...              ...       ...
# 5819074                 1031          1029.0             -2.0      36.0
# 5819075                 1031          1031.0              0.0       9.0
# 5819076                 1031          1025.0             -6.0      18.0
# 5819077                 1031          1022.0             -9.0      22.0
# 5819078                 1032          1030.0             -2.0      15.0
#
#          WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  \
# 0            1600.0           242.0         232.0     209.0      1389
# 1            1535.0           184.0         178.0     152.0      1097
# 2            1540.0           120.0          95.0      78.0       606
# 3            1543.0           104.0         102.0      80.0       528
# 4            1555.0            69.0          75.0      45.0       241
# ...             ...             ...           ...       ...       ...
# 5819074      1105.0           194.0         183.0     144.0      1035
# 5819075      1040.0            76.0          63.0      49.0       271
# 5819076      1043.0            60.0          56.0      34.0       228
# 5819077      1044.0           144.0         150.0     121.0       851
# 5819078      1045.0           150.0         146.0     125.0       818
#
#          WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY  \
# 0           1829.0      5.0               1831        1834.0            3.0
# 1           1807.0     11.0               1833        1818.0          -15.0
# 2           1758.0      6.0               1829        1804.0          -25.0
# 3           1703.0      5.0               1713        1708.0           -5.0
# 4           1540.0      3.0               1539        1543.0            4.0
# ...            ...      ...                ...           ...            ...
# 5819074     1329.0      3.0               1345        1332.0          -13.0
# 5819075     1029.0      5.0               1047        1034.0          -13.0
# 5819076     1117.0      4.0               1131        1121.0          -10.0
# 5819077     1245.0      7.0               1255        1252.0           -3.0
# 5819078     1250.0      6.0               1302        1256.0           -6.0
#
#          DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0               0          0                None               NaN
# 1               0          0                None               NaN
# 2               0          0                None               NaN
# 3               0          0                None               NaN
# 4               0          0                None               NaN
# ...           ...        ...                 ...               ...
# 5819074         0          0                None               NaN
# 5819075         0          0                None               NaN
# 5819076         0          0                None               NaN
# 5819077         0          0                None               NaN
# 5819078         0          0                None               NaN
#
#          SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  \
# 0                   NaN            NaN                  NaN            NaN
# 1                   NaN            NaN                  NaN            NaN
# 2                   NaN            NaN                  NaN            NaN
# 3                   NaN            NaN                  NaN            NaN
# 4                   NaN            NaN                  NaN            NaN
# ...                 ...            ...                  ...            ...
# 5819074             NaN            NaN                  NaN            NaN
# 5819075             NaN            NaN                  NaN            NaN
# 5819076             NaN            NaN                  NaN            NaN
# 5819077             NaN            NaN                  NaN            NaN
# 5819078             NaN            NaN                  NaN            NaN
#
#            FLY_DATE                      AIRLINE  \
# 0        2024-04-23       American Airlines Inc.
# 1        2024-04-23              JetBlue Airways
# 2        2024-04-23         Delta Air Lines Inc.
# 3        2024-04-23         Delta Air Lines Inc.
# 4        2024-04-23  Atlantic Southeast Airlines
# ...             ...                          ...
# 5819074  2024-03-24         Delta Air Lines Inc.
# 5819075  2024-03-24         Delta Air Lines Inc.
# 5819076  2024-03-24         Delta Air Lines Inc.
# 5819077  2024-03-24       Frontier Airlines Inc.
# 5819078  2024-03-24              JetBlue Airways
#
#                                            ORIGIN_AIRPORT   ORIGIN_CITY  \
# 0                 LaGuardia Airport (Marine Air Terminal)      New York
# 1                              Westchester County Airport  White Plains
# 2                    Chicago O'Hare International Airport       Chicago
# 3        Hartsfield-Jackson Atlanta International Airport       Atlanta
# 4        Hartsfield-Jackson Atlanta International Airport       Atlanta
# ...                                                   ...           ...
# 5819074           LaGuardia Airport (Marine Air Terminal)      New York
# 5819075  Hartsfield-Jackson Atlanta International Airport       Atlanta
# 5819076      Minneapolis-Saint Paul International Airport   Minneapolis
# 5819077                  Harrisburg International Airport    Harrisburg
# 5819078  Gen. Edward Lawrence Logan International Airport        Boston
#
#         ORIGIN_STATE ORIGIN_COUNTRY  ORIGIN_LATITUDE  ORIGIN_LONGITUDE  \
# 0                 NY            USA         40.77724         -73.87261
# 1                 NY            USA         41.06696         -73.70757
# 2                 IL            USA         41.97960         -87.90446
# 3                 GA            USA         33.64044         -84.42694
# 4                 GA            USA         33.64044         -84.42694
# ...              ...            ...              ...               ...
# 5819074           NY            USA         40.77724         -73.87261
# 5819075           GA            USA         33.64044         -84.42694
# 5819076           MN            USA         44.88055         -93.21692
# 5819077           PA            USA         40.19350         -76.76340
# 5819078           MA            USA         42.36435         -71.00518
#
#                                               DEST_AIRPORT  \
# 0                  Dallas/Fort Worth International Airport
# 1          Fort Lauderdale-Hollywood International Airport
# 2         Hartsfield-Jackson Atlanta International Airport
# 3                            Akron-Canton Regional Airport
# 4                         Golden Triangle Regional Airport
# ...                                                    ...
# 5819074                   Palm Beach International Airport
# 5819075  Pensacola International Airport (Pensacola Gul...
# 5819076                       Dane County Regional Airport
# 5819077                      Orlando International Airport
# 5819078    Charleston International Airport/Charleston AFB
#
#                               DEST_CITY DEST_STATE DEST_COUNTRY  \
# 0                     Dallas-Fort Worth         TX          USA
# 1                        Ft. Lauderdale         FL          USA
# 2                               Atlanta         GA          USA
# 3                                 Akron         OH          USA
# 4        Columbus-Starkville-West Point         MS          USA
# ...                                 ...        ...          ...
# 5819074                 West Palm Beach         FL          USA
# 5819075                       Pensacola         FL          USA
# 5819076                         Madison         WI          USA
# 5819077                         Orlando         FL          USA
# 5819078                      Charleston         SC          USA
#
#          DEST_LATITUDE  DEST_LONGITUDE
# 0             32.89595       -97.03720
# 1             26.07258       -80.15275
# 2             33.64044       -84.42694
# 3             40.91631       -81.44247
# 4             33.45033       -88.59137
# ...                ...             ...
# 5819074       26.68316       -80.09559
# 5819075       30.47331       -87.18744
# 5819076       43.13986       -89.33751
# 5819077       28.42889       -81.31603
# 5819078       32.89865       -80.04051
#
# [5819079 rows x 45 columns]

# %% [markdown]
# # Filtering data for specific airlines

# %%
# Defining the list of airlines to include in the filtered DataFrame
#options = ['Southwest Airlines Co.', 'Delta Air Lines Inc.']
options = ['Southwest Airlines Co.']
#df.replace({'AIRLINE':'Southwest Airlines Co.'}, {'AIRLINE': 'Southwest airlines'}, regex=True)
#df.replace({'AIRLINE':'Delta Air Lines Inc.'}, {'AIRLINE': 'Delta airlines'}, regex=True)

# Selecting rows where the 'AIRLINE' column matches one of the specified airlines
flights = df.loc[df['AIRLINE'].isin(options)]
flights
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE__CODE  FLIGHT_NUMBER  \
# 39       2024      4   23            4            WN            395
# 40       2024      4   23            4            WN           4989
# 41       2024      4   23            4            WN           1878
# 42       2024      4   23            4            WN            300
# 43       2024      4   23            4            WN            573
# ...       ...    ...  ...          ...           ...            ...
# 5819045  2024      3   24            2            WN            759
# 5819046  2024      3   24            2            WN            566
# 5819047  2024      3   24            2            WN            760
# 5819048  2024      3   24            2            WN            336
# 5819049  2024      3   24            2            WN            751
#
#         TAIL_NUMBER ORIGIN_AIRPORT_CODE DESTINATION_AIRPORT_CODE  \
# 39           N7740A                 LAS                      SAN
# 40           N647SW                 ATL                      IND
# 41           N8642E                 SEA                      DEN
# 42           N960WN                 SMF                      BUR
# 43           N244WN                 SMF                      LAS
# ...             ...                 ...                      ...
# 5819045      N236WN                 PHX                      CLE
# 5819046      N7727A                 PHX                      DTW
# 5819047      N7736A                 OAK                      BUR
# 5819048      N7748A                 OAK                      LAX
# 5819049      N360SW                 OAK                      ONT
#
#          SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY  TAXI_OUT  \
# 39                      1530          1555.0             25.0      26.0
# 40                      1530          1531.0              1.0      18.0
# 41                      1530          1537.0              7.0      13.0
# 42                      1530          1534.0              4.0       7.0
# 43                      1530          1604.0             34.0      12.0
# ...                      ...             ...              ...       ...
# 5819045                 1030          1043.0             13.0      23.0
# 5819046                 1030          1123.0             53.0      12.0
# 5819047                 1030          1028.0             -2.0       6.0
# 5819048                 1030          1028.0             -2.0      10.0
# 5819049                 1030          1029.0             -1.0      17.0
#
#          WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  \
# 39           1621.0            65.0          74.0      45.0       258
# 40           1549.0           100.0          96.0      73.0       432
# 41           1550.0           165.0         147.0     128.0      1024
# 42           1541.0            65.0          60.0      50.0       358
# 43           1616.0            80.0          77.0      61.0       397
# ...             ...             ...           ...       ...       ...
# 5819045      1106.0           230.0         225.0     197.0      1737
# 5819046      1135.0           230.0         209.0     191.0      1671
# 5819047      1034.0            65.0          56.0      46.0       325
# 5819048      1038.0            75.0          74.0      48.0       337
# 5819049      1046.0            75.0          76.0      55.0       362
#
#          WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY  \
# 39          1706.0      3.0               1635        1709.0           34.0
# 40          1702.0      5.0               1710        1707.0           -3.0
# 41          1858.0      6.0               1915        1904.0          -11.0
# 42          1631.0      3.0               1635        1634.0           -1.0
# 43          1717.0      4.0               1650        1721.0           31.0
# ...            ...      ...                ...           ...            ...
# 5819045     1723.0      5.0               1720        1728.0            8.0
# 5819046     1746.0      6.0               1720        1752.0           32.0
# 5819047     1120.0      4.0               1135        1124.0          -11.0
# 5819048     1126.0     16.0               1145        1142.0           -3.0
# 5819049     1141.0      4.0               1145        1145.0            0.0
#
#          DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 39              0          0                None               9.0
# 40              0          0                None               NaN
# 41              0          0                None               NaN
# 42              0          0                None               NaN
# 43              0          0                None               6.0
# ...           ...        ...                 ...               ...
# 5819045         0          0                None               NaN
# 5819046         0          0                None               0.0
# 5819047         0          0                None               NaN
# 5819048         0          0                None               NaN
# 5819049         0          0                None               NaN
#
#          SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  \
# 39                  0.0            5.0                 20.0            0.0
# 40                  NaN            NaN                  NaN            NaN
# 41                  NaN            NaN                  NaN            NaN
# 42                  NaN            NaN                  NaN            NaN
# 43                  0.0            0.0                 25.0            0.0
# ...                 ...            ...                  ...            ...
# 5819045             NaN            NaN                  NaN            NaN
# 5819046             0.0           12.0                 20.0            0.0
# 5819047             NaN            NaN                  NaN            NaN
# 5819048             NaN            NaN                  NaN            NaN
# 5819049             NaN            NaN                  NaN            NaN
#
#            FLY_DATE                 AIRLINE  \
# 39       2024-04-23  Southwest Airlines Co.
# 40       2024-04-23  Southwest Airlines Co.
# 41       2024-04-23  Southwest Airlines Co.
# 42       2024-04-23  Southwest Airlines Co.
# 43       2024-04-23  Southwest Airlines Co.
# ...             ...                     ...
# 5819045  2024-03-24  Southwest Airlines Co.
# 5819046  2024-03-24  Southwest Airlines Co.
# 5819047  2024-03-24  Southwest Airlines Co.
# 5819048  2024-03-24  Southwest Airlines Co.
# 5819049  2024-03-24  Southwest Airlines Co.
#
#                                            ORIGIN_AIRPORT ORIGIN_CITY  \
# 39                         McCarran International Airport   Las Vegas
# 40       Hartsfield-Jackson Atlanta International Airport     Atlanta
# 41                   Seattle-Tacoma International Airport     Seattle
# 42                       Sacramento International Airport  Sacramento
# 43                       Sacramento International Airport  Sacramento
# ...                                                   ...         ...
# 5819045          Phoenix Sky Harbor International Airport     Phoenix
# 5819046          Phoenix Sky Harbor International Airport     Phoenix
# 5819047                     Oakland International Airport     Oakland
# 5819048                     Oakland International Airport     Oakland
# 5819049                     Oakland International Airport     Oakland
#
#         ORIGIN_STATE ORIGIN_COUNTRY  ORIGIN_LATITUDE  ORIGIN_LONGITUDE  \
# 39                NV            USA         36.08036        -115.15233
# 40                GA            USA         33.64044         -84.42694
# 41                WA            USA         47.44898        -122.30931
# 42                CA            USA         38.69542        -121.59077
# 43                CA            USA         38.69542        -121.59077
# ...              ...            ...              ...               ...
# 5819045           AZ            USA         33.43417        -112.00806
# 5819046           AZ            USA         33.43417        -112.00806
# 5819047           CA            USA         37.72129        -122.22072
# 5819048           CA            USA         37.72129        -122.22072
# 5819049           CA            USA         37.72129        -122.22072
#
#                                               DEST_AIRPORT     DEST_CITY  \
# 39       San Diego International Airport (Lindbergh Field)     San Diego
# 40                      Indianapolis International Airport  Indianapolis
# 41                            Denver International Airport        Denver
# 42            Bob Hope Airport (Hollywood Burbank Airport)       Burbank
# 43                          McCarran International Airport     Las Vegas
# ...                                                    ...           ...
# 5819045            Cleveland Hopkins International Airport     Cleveland
# 5819046                       Detroit Metropolitan Airport       Detroit
# 5819047       Bob Hope Airport (Hollywood Burbank Airport)       Burbank
# 5819048                  Los Angeles International Airport   Los Angeles
# 5819049                      Ontario International Airport       Ontario
#
#         DEST_STATE DEST_COUNTRY  DEST_LATITUDE  DEST_LONGITUDE
# 39              CA          USA       32.73356      -117.18966
# 40              IN          USA       39.71733       -86.29438
# 41              CO          USA       39.85841      -104.66700
# 42              CA          USA       34.20062      -118.35850
# 43              NV          USA       36.08036      -115.15233
# ...            ...          ...            ...             ...
# 5819045         OH          USA       41.41089       -81.84940
# 5819046         MI          USA       42.21206       -83.34884
# 5819047         CA          USA       34.20062      -118.35850
# 5819048         CA          USA       33.94254      -118.40807
# 5819049         CA          USA       34.05600      -117.60119
#
# [1261855 rows x 45 columns]

# %%
flights = flights.dropna(subset = 'ARRIVAL_DELAY')

# %% [markdown]
# # Creating a copy of the filtered flights data

# %%
# This ensures that any modifications made to 'flights_needed_data' do not affect the original 'flights' DataFrame
flights_needed_data = flights.copy()

# %%
flights_needed_data.shape
#(2137736, 45)
# Out:
# (1242403, 45)

# %%
flights_needed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1242403 entries, 39 to 5819049
# Data columns (total 45 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   YEAR                      1242403 non-null  int16
#  1   MONTH                     1242403 non-null  int8
#  2   DAY                       1242403 non-null  int8
#  3   DAY_OF_WEEK               1242403 non-null  int8
#  4   AIRLINE__CODE             1242403 non-null  object
#  5   FLIGHT_NUMBER             1242403 non-null  int16
#  6   TAIL_NUMBER               1242403 non-null  object
#  7   ORIGIN_AIRPORT_CODE       1242403 non-null  object
#  8   DESTINATION_AIRPORT_CODE  1242403 non-null  object
#  9   SCHEDULED_DEPARTURE       1242403 non-null  int16
#  10  DEPARTURE_TIME            1242403 non-null  float64
#  11  DEPARTURE_DELAY           1242403 non-null  float64
#  12  TAXI_OUT                  1242403 non-null  float64
#  13  WHEELS_OFF                1242403 non-null  float64
#  14  SCHEDULED_TIME            1242403 non-null  float64
#  15  ELAPSED_TIME              1242403 non-null  float64
#  16  AIR_TIME                  1242403 non-null  float64
#  17  DISTANCE                  1242403 non-null  int16
#  18  WHEELS_ON                 1242403 non-null  float64
#  19  TAXI_IN                   1242403 non-null  float64
#  20  SCHEDULED_ARRIVAL         1242403 non-null  int16
#  21  ARRIVAL_TIME              1242403 non-null  float64
#  22  ARRIVAL_DELAY             1242403 non-null  float64
#  23  DIVERTED                  1242403 non-null  int8
#  24  CANCELLED                 1242403 non-null  int8
#  25  CANCELLATION_REASON       0 non-null        object
#  26  AIR_SYSTEM_DELAY          236626 non-null   float64
#  27  SECURITY_DELAY            236626 non-null   float64
#  28  AIRLINE_DELAY             236626 non-null   float64
#  29  LATE_AIRCRAFT_DELAY       236626 non-null   float64
#  30  WEATHER_DELAY             236626 non-null   float64
#  31  FLY_DATE                  1242403 non-null  object
#  32  AIRLINE                   1242403 non-null  object
#  33  ORIGIN_AIRPORT            1138350 non-null  object
#  34  ORIGIN_CITY               1138350 non-null  object
#  35  ORIGIN_STATE              1138350 non-null  object
#  36  ORIGIN_COUNTRY            1138350 non-null  object
#  37  ORIGIN_LATITUDE           1136750 non-null  float64
#  38  ORIGIN_LONGITUDE          1136750 non-null  float64
#  39  DEST_AIRPORT              1138350 non-null  object
#  40  DEST_CITY                 1138350 non-null  object
#  41  DEST_STATE                1138350 non-null  object
#  42  DEST_COUNTRY              1138350 non-null  object
#  43  DEST_LATITUDE             1136752 non-null  float64
#  44  DEST_LONGITUDE            1136752 non-null  float64
# dtypes: float64(20), int16(5), int8(5), object(15)
# memory usage: 359.0+ MB

# %%
flights_needed_data.head()
# Out:
#     YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE__CODE  FLIGHT_NUMBER TAIL_NUMBER  \
# 39  2024      4   23            4            WN            395      N7740A
# 40  2024      4   23            4            WN           4989      N647SW
# 41  2024      4   23            4            WN           1878      N8642E
# 42  2024      4   23            4            WN            300      N960WN
# 43  2024      4   23            4            WN            573      N244WN
#
#    ORIGIN_AIRPORT_CODE DESTINATION_AIRPORT_CODE  SCHEDULED_DEPARTURE  \
# 39                 LAS                      SAN                 1530
# 40                 ATL                      IND                 1530
# 41                 SEA                      DEN                 1530
# 42                 SMF                      BUR                 1530
# 43                 SMF                      LAS                 1530
#
#     DEPARTURE_TIME  DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  \
# 39          1555.0             25.0      26.0      1621.0            65.0
# 40          1531.0              1.0      18.0      1549.0           100.0
# 41          1537.0              7.0      13.0      1550.0           165.0
# 42          1534.0              4.0       7.0      1541.0            65.0
# 43          1604.0             34.0      12.0      1616.0            80.0
#
#     ELAPSED_TIME  AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  \
# 39          74.0      45.0       258     1706.0      3.0               1635
# 40          96.0      73.0       432     1702.0      5.0               1710
# 41         147.0     128.0      1024     1858.0      6.0               1915
# 42          60.0      50.0       358     1631.0      3.0               1635
# 43          77.0      61.0       397     1717.0      4.0               1650
#
#     ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  \
# 39        1709.0           34.0         0          0                None
# 40        1707.0           -3.0         0          0                None
# 41        1904.0          -11.0         0          0                None
# 42        1634.0           -1.0         0          0                None
# 43        1721.0           31.0         0          0                None
#
#     AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 39               9.0             0.0            5.0                 20.0
# 40               NaN             NaN            NaN                  NaN
# 41               NaN             NaN            NaN                  NaN
# 42               NaN             NaN            NaN                  NaN
# 43               6.0             0.0            0.0                 25.0
#
#     WEATHER_DELAY    FLY_DATE                 AIRLINE  \
# 39            0.0  2024-04-23  Southwest Airlines Co.
# 40            NaN  2024-04-23  Southwest Airlines Co.
# 41            NaN  2024-04-23  Southwest Airlines Co.
# 42            NaN  2024-04-23  Southwest Airlines Co.
# 43            0.0  2024-04-23  Southwest Airlines Co.
#
#                                       ORIGIN_AIRPORT ORIGIN_CITY ORIGIN_STATE  \
# 39                    McCarran International Airport   Las Vegas           NV
# 40  Hartsfield-Jackson Atlanta International Airport     Atlanta           GA
# 41              Seattle-Tacoma International Airport     Seattle           WA
# 42                  Sacramento International Airport  Sacramento           CA
# 43                  Sacramento International Airport  Sacramento           CA
#
#    ORIGIN_COUNTRY  ORIGIN_LATITUDE  ORIGIN_LONGITUDE  \
# 39            USA         36.08036        -115.15233
# 40            USA         33.64044         -84.42694
# 41            USA         47.44898        -122.30931
# 42            USA         38.69542        -121.59077
# 43            USA         38.69542        -121.59077
#
#                                          DEST_AIRPORT     DEST_CITY  \
# 39  San Diego International Airport (Lindbergh Field)     San Diego
# 40                 Indianapolis International Airport  Indianapolis
# 41                       Denver International Airport        Denver
# 42       Bob Hope Airport (Hollywood Burbank Airport)       Burbank
# 43                     McCarran International Airport     Las Vegas
#
#    DEST_STATE DEST_COUNTRY  DEST_LATITUDE  DEST_LONGITUDE
# 39         CA          USA       32.73356      -117.18966
# 40         IN          USA       39.71733       -86.29438
# 41         CO          USA       39.85841      -104.66700
# 42         CA          USA       34.20062      -118.35850
# 43         NV          USA       36.08036      -115.15233

# %% [markdown]
# # Function to categorize scheduled arrival times into time segments

# %%
def categorize_time(SCHEDULED_ARRIVAL):
    # Categorize based on scheduled arrival time in 24-hour format
    if 500 <= SCHEDULED_ARRIVAL < 800:
        return 'Early morning'
    elif 800 <= SCHEDULED_ARRIVAL < 1100:
        return 'Late morning'
    elif 1100 <= SCHEDULED_ARRIVAL < 1400:
        return 'Around noon'
    elif 1400 <= SCHEDULED_ARRIVAL < 1700:
        return 'Afternoon'
    elif 1700 <= SCHEDULED_ARRIVAL < 2000:
        return 'Evening'
    elif 2000 <= SCHEDULED_ARRIVAL < 2300:
        return 'Night'
    elif SCHEDULED_ARRIVAL >= 2300 or SCHEDULED_ARRIVAL < 200:
        return 'Late night'
    elif 200 <= SCHEDULED_ARRIVAL < 500:
        return 'Dawn'

# Apply categorize_time function to the 'SCHEDULED_ARRIVAL' column to create 'ARRIVAL_TIME_SEGMENT'
flights_needed_data['ARRIVAL_TIME_SEGMENT'] = flights_needed_data['SCHEDULED_ARRIVAL'].apply(categorize_time)

# %%
flights_needed_data
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE__CODE  FLIGHT_NUMBER  \
# 39       2024      4   23            4            WN            395
# 40       2024      4   23            4            WN           4989
# 41       2024      4   23            4            WN           1878
# 42       2024      4   23            4            WN            300
# 43       2024      4   23            4            WN            573
# ...       ...    ...  ...          ...           ...            ...
# 5819045  2024      3   24            2            WN            759
# 5819046  2024      3   24            2            WN            566
# 5819047  2024      3   24            2            WN            760
# 5819048  2024      3   24            2            WN            336
# 5819049  2024      3   24            2            WN            751
#
#         TAIL_NUMBER ORIGIN_AIRPORT_CODE DESTINATION_AIRPORT_CODE  \
# 39           N7740A                 LAS                      SAN
# 40           N647SW                 ATL                      IND
# 41           N8642E                 SEA                      DEN
# 42           N960WN                 SMF                      BUR
# 43           N244WN                 SMF                      LAS
# ...             ...                 ...                      ...
# 5819045      N236WN                 PHX                      CLE
# 5819046      N7727A                 PHX                      DTW
# 5819047      N7736A                 OAK                      BUR
# 5819048      N7748A                 OAK                      LAX
# 5819049      N360SW                 OAK                      ONT
#
#          SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY  TAXI_OUT  \
# 39                      1530          1555.0             25.0      26.0
# 40                      1530          1531.0              1.0      18.0
# 41                      1530          1537.0              7.0      13.0
# 42                      1530          1534.0              4.0       7.0
# 43                      1530          1604.0             34.0      12.0
# ...                      ...             ...              ...       ...
# 5819045                 1030          1043.0             13.0      23.0
# 5819046                 1030          1123.0             53.0      12.0
# 5819047                 1030          1028.0             -2.0       6.0
# 5819048                 1030          1028.0             -2.0      10.0
# 5819049                 1030          1029.0             -1.0      17.0
#
#          WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  \
# 39           1621.0            65.0          74.0      45.0       258
# 40           1549.0           100.0          96.0      73.0       432
# 41           1550.0           165.0         147.0     128.0      1024
# 42           1541.0            65.0          60.0      50.0       358
# 43           1616.0            80.0          77.0      61.0       397
# ...             ...             ...           ...       ...       ...
# 5819045      1106.0           230.0         225.0     197.0      1737
# 5819046      1135.0           230.0         209.0     191.0      1671
# 5819047      1034.0            65.0          56.0      46.0       325
# 5819048      1038.0            75.0          74.0      48.0       337
# 5819049      1046.0            75.0          76.0      55.0       362
#
#          WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY  \
# 39          1706.0      3.0               1635        1709.0           34.0
# 40          1702.0      5.0               1710        1707.0           -3.0
# 41          1858.0      6.0               1915        1904.0          -11.0
# 42          1631.0      3.0               1635        1634.0           -1.0
# 43          1717.0      4.0               1650        1721.0           31.0
# ...            ...      ...                ...           ...            ...
# 5819045     1723.0      5.0               1720        1728.0            8.0
# 5819046     1746.0      6.0               1720        1752.0           32.0
# 5819047     1120.0      4.0               1135        1124.0          -11.0
# 5819048     1126.0     16.0               1145        1142.0           -3.0
# 5819049     1141.0      4.0               1145        1145.0            0.0
#
#          DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 39              0          0                None               9.0
# 40              0          0                None               NaN
# 41              0          0                None               NaN
# 42              0          0                None               NaN
# 43              0          0                None               6.0
# ...           ...        ...                 ...               ...
# 5819045         0          0                None               NaN
# 5819046         0          0                None               0.0
# 5819047         0          0                None               NaN
# 5819048         0          0                None               NaN
# 5819049         0          0                None               NaN
#
#          SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  \
# 39                  0.0            5.0                 20.0            0.0
# 40                  NaN            NaN                  NaN            NaN
# 41                  NaN            NaN                  NaN            NaN
# 42                  NaN            NaN                  NaN            NaN
# 43                  0.0            0.0                 25.0            0.0
# ...                 ...            ...                  ...            ...
# 5819045             NaN            NaN                  NaN            NaN
# 5819046             0.0           12.0                 20.0            0.0
# 5819047             NaN            NaN                  NaN            NaN
# 5819048             NaN            NaN                  NaN            NaN
# 5819049             NaN            NaN                  NaN            NaN
#
#            FLY_DATE                 AIRLINE  \
# 39       2024-04-23  Southwest Airlines Co.
# 40       2024-04-23  Southwest Airlines Co.
# 41       2024-04-23  Southwest Airlines Co.
# 42       2024-04-23  Southwest Airlines Co.
# 43       2024-04-23  Southwest Airlines Co.
# ...             ...                     ...
# 5819045  2024-03-24  Southwest Airlines Co.
# 5819046  2024-03-24  Southwest Airlines Co.
# 5819047  2024-03-24  Southwest Airlines Co.
# 5819048  2024-03-24  Southwest Airlines Co.
# 5819049  2024-03-24  Southwest Airlines Co.
#
#                                            ORIGIN_AIRPORT ORIGIN_CITY  \
# 39                         McCarran International Airport   Las Vegas
# 40       Hartsfield-Jackson Atlanta International Airport     Atlanta
# 41                   Seattle-Tacoma International Airport     Seattle
# 42                       Sacramento International Airport  Sacramento
# 43                       Sacramento International Airport  Sacramento
# ...                                                   ...         ...
# 5819045          Phoenix Sky Harbor International Airport     Phoenix
# 5819046          Phoenix Sky Harbor International Airport     Phoenix
# 5819047                     Oakland International Airport     Oakland
# 5819048                     Oakland International Airport     Oakland
# 5819049                     Oakland International Airport     Oakland
#
#         ORIGIN_STATE ORIGIN_COUNTRY  ORIGIN_LATITUDE  ORIGIN_LONGITUDE  \
# 39                NV            USA         36.08036        -115.15233
# 40                GA            USA         33.64044         -84.42694
# 41                WA            USA         47.44898        -122.30931
# 42                CA            USA         38.69542        -121.59077
# 43                CA            USA         38.69542        -121.59077
# ...              ...            ...              ...               ...
# 5819045           AZ            USA         33.43417        -112.00806
# 5819046           AZ            USA         33.43417        -112.00806
# 5819047           CA            USA         37.72129        -122.22072
# 5819048           CA            USA         37.72129        -122.22072
# 5819049           CA            USA         37.72129        -122.22072
#
#                                               DEST_AIRPORT     DEST_CITY  \
# 39       San Diego International Airport (Lindbergh Field)     San Diego
# 40                      Indianapolis International Airport  Indianapolis
# 41                            Denver International Airport        Denver
# 42            Bob Hope Airport (Hollywood Burbank Airport)       Burbank
# 43                          McCarran International Airport     Las Vegas
# ...                                                    ...           ...
# 5819045            Cleveland Hopkins International Airport     Cleveland
# 5819046                       Detroit Metropolitan Airport       Detroit
# 5819047       Bob Hope Airport (Hollywood Burbank Airport)       Burbank
# 5819048                  Los Angeles International Airport   Los Angeles
# 5819049                      Ontario International Airport       Ontario
#
#         DEST_STATE DEST_COUNTRY  DEST_LATITUDE  DEST_LONGITUDE  \
# 39              CA          USA       32.73356      -117.18966
# 40              IN          USA       39.71733       -86.29438
# 41              CO          USA       39.85841      -104.66700
# 42              CA          USA       34.20062      -118.35850
# 43              NV          USA       36.08036      -115.15233
# ...            ...          ...            ...             ...
# 5819045         OH          USA       41.41089       -81.84940
# 5819046         MI          USA       42.21206       -83.34884
# 5819047         CA          USA       34.20062      -118.35850
# 5819048         CA          USA       33.94254      -118.40807
# 5819049         CA          USA       34.05600      -117.60119
#
#         ARRIVAL_TIME_SEGMENT
# 39                 Afternoon
# 40                   Evening
# 41                   Evening
# 42                 Afternoon
# 43                 Afternoon
# ...                      ...
# 5819045              Evening
# 5819046              Evening
# 5819047          Around noon
# 5819048          Around noon
# 5819049          Around noon
#
# [1242403 rows x 46 columns]

# %%
flights['AIRLINE__CODE'].unique()
# Out:
# array(['WN'], dtype=object)

# %%
flights_needed_data.value_counts('DIVERTED')
# Out:
# DIVERTED
# 0    1242403
# Name: count, dtype: int64

# %%
flights_needed_data['FLIGHT_NUMBER'] = flights_needed_data['FLIGHT_NUMBER'].astype(str)

# %%
flights_needed_data['MONTH'] = flights_needed_data['MONTH'].astype(str)
flights_needed_data['DAY'] = flights_needed_data['DAY'].astype(str)
flights_needed_data['DAY_OF_WEEK'] = flights_needed_data['DAY_OF_WEEK'].astype(str)
flights_needed_data['DIVERTED'] = flights_needed_data['DIVERTED'].astype(str)
flights_needed_data['CANCELLED'] = flights_needed_data['CANCELLED'].astype(str)
flights_needed_data['CANCELLED'] = flights_needed_data['CANCELLED'].astype(str)

# %%
flights_needed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1242403 entries, 39 to 5819049
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   YEAR                      1242403 non-null  int16
#  1   MONTH                     1242403 non-null  object
#  2   DAY                       1242403 non-null  object
#  3   DAY_OF_WEEK               1242403 non-null  object
#  4   AIRLINE__CODE             1242403 non-null  object
#  5   FLIGHT_NUMBER             1242403 non-null  object
#  6   TAIL_NUMBER               1242403 non-null  object
#  7   ORIGIN_AIRPORT_CODE       1242403 non-null  object
#  8   DESTINATION_AIRPORT_CODE  1242403 non-null  object
#  9   SCHEDULED_DEPARTURE       1242403 non-null  int16
#  10  DEPARTURE_TIME            1242403 non-null  float64
#  11  DEPARTURE_DELAY           1242403 non-null  float64
#  12  TAXI_OUT                  1242403 non-null  float64
#  13  WHEELS_OFF                1242403 non-null  float64
#  14  SCHEDULED_TIME            1242403 non-null  float64
#  15  ELAPSED_TIME              1242403 non-null  float64
#  16  AIR_TIME                  1242403 non-null  float64
#  17  DISTANCE                  1242403 non-null  int16
#  18  WHEELS_ON                 1242403 non-null  float64
#  19  TAXI_IN                   1242403 non-null  float64
#  20  SCHEDULED_ARRIVAL         1242403 non-null  int16
#  21  ARRIVAL_TIME              1242403 non-null  float64
#  22  ARRIVAL_DELAY             1242403 non-null  float64
#  23  DIVERTED                  1242403 non-null  object
#  24  CANCELLED                 1242403 non-null  object
#  25  CANCELLATION_REASON       0 non-null        object
#  26  AIR_SYSTEM_DELAY          236626 non-null   float64
#  27  SECURITY_DELAY            236626 non-null   float64
#  28  AIRLINE_DELAY             236626 non-null   float64
#  29  LATE_AIRCRAFT_DELAY       236626 non-null   float64
#  30  WEATHER_DELAY             236626 non-null   float64
#  31  FLY_DATE                  1242403 non-null  object
#  32  AIRLINE                   1242403 non-null  object
#  33  ORIGIN_AIRPORT            1138350 non-null  object
#  34  ORIGIN_CITY               1138350 non-null  object
#  35  ORIGIN_STATE              1138350 non-null  object
#  36  ORIGIN_COUNTRY            1138350 non-null  object
#  37  ORIGIN_LATITUDE           1136750 non-null  float64
#  38  ORIGIN_LONGITUDE          1136750 non-null  float64
#  39  DEST_AIRPORT              1138350 non-null  object
#  40  DEST_CITY                 1138350 non-null  object
#  41  DEST_STATE                1138350 non-null  object
#  42  DEST_COUNTRY              1138350 non-null  object
#  43  DEST_LATITUDE             1136752 non-null  float64
#  44  DEST_LONGITUDE            1136752 non-null  float64
#  45  ARRIVAL_TIME_SEGMENT      1242403 non-null  object
# dtypes: float64(20), int16(4), object(22)
# memory usage: 417.1+ MB

# %%
flights_needed_data.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE__CODE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT_CODE', 'DESTINATION_AIRPORT_CODE',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY', 'FLY_DATE', 'AIRLINE',
#        'ORIGIN_AIRPORT', 'ORIGIN_CITY', 'ORIGIN_STATE', 'ORIGIN_COUNTRY',
#        'ORIGIN_LATITUDE', 'ORIGIN_LONGITUDE', 'DEST_AIRPORT', 'DEST_CITY',
#        'DEST_STATE', 'DEST_COUNTRY', 'DEST_LATITUDE', 'DEST_LONGITUDE',
#        'ARRIVAL_TIME_SEGMENT'],
#       dtype='object')

# %% [markdown]
# # Correlations matrix

# %%
corr_matrix = flights_needed_data.select_dtypes([int, 'float']).corr()

# Plot the correlation matrix
plt.figure(figsize=(8, 6))
plt.matshow(corr_matrix, cmap='coolwarm', fignum=1)
plt.colorbar()
plt.xticks(range(len(corr_matrix.columns)), corr_matrix.columns, rotation=45)
plt.yticks(range(len(corr_matrix.columns)), corr_matrix.columns)
plt.title("Correlation Matrix", pad=20)
plt.show()

# %%
# Set threshold values
target_corr_threshold = 0.2
feature_corr_threshold = 0.8

# Step 1: Select features with high correlation with the target
target_corr = corr_matrix['ARRIVAL_DELAY'].abs()
high_corr_features = target_corr[target_corr > target_corr_threshold].index.tolist()
high_corr_features.remove('ARRIVAL_DELAY')  # Remove the target itself

# Step 2: Filter out highly correlated features among selected features
filtered_features = high_corr_features.copy()
for feature in high_corr_features:
    for other_feature in high_corr_features:
        if feature != other_feature and corr_matrix[feature][other_feature] > feature_corr_threshold:
            if other_feature in filtered_features:
                filtered_features.remove(other_feature)

print("Selected features for model training:", filtered_features)
# Out:
# Selected features for model training: ['DEPARTURE_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY']

# %%
from scipy.stats import chi2_contingency
from sklearn.preprocessing import LabelEncoder

def cramers_v(x, y):
    contingency_table = pd.crosstab(x, y)
    if contingency_table.size == 0:
        return np.nan 

    chi2, _, _, _ = chi2_contingency(contingency_table)
    n = contingency_table.sum().sum()
    r, k = contingency_table.shape
    return np.sqrt(chi2 / (n * (min(k-1, r-1))))

categorical_cols = flights_needed_data.select_dtypes(include=['object', 'category']).columns

cramers_v_matrix = pd.DataFrame(index=categorical_cols, columns=categorical_cols)

for col1 in categorical_cols:
    for col2 in categorical_cols:
        if col1 == col2:
            cramers_v_matrix.loc[col1, col2] = 1.0 
        else:
            cramers_v_matrix.loc[col1, col2] = cramers_v(flights_needed_data[col1], flights_needed_data[col2])

print(cramers_v_matrix)
# Out:
#                              MONTH       DAY DAY_OF_WEEK AIRLINE__CODE  \
# MONTH                          1.0  0.047854    0.044206           NaN
# DAY                       0.047854       1.0    0.159043           NaN
# DAY_OF_WEEK               0.044206  0.159043         1.0           NaN
# AIRLINE__CODE                  NaN       NaN         NaN           1.0
# FLIGHT_NUMBER              0.28379  0.090934    0.251289           NaN
# TAIL_NUMBER               0.085246  0.018074    0.017505           NaN
# ORIGIN_AIRPORT_CODE       0.302169  0.006655    0.022212           NaN
# DESTINATION_AIRPORT_CODE  0.302174  0.006755    0.022263           NaN
# DIVERTED                       NaN       NaN         NaN           NaN
# CANCELLED                      NaN       NaN         NaN           NaN
# CANCELLATION_REASON            NaN       NaN         NaN           NaN
# FLY_DATE                       1.0       1.0         1.0           NaN
# AIRLINE                        NaN       NaN         NaN           NaN
# ORIGIN_AIRPORT            0.020905  0.003396    0.018471           NaN
# ORIGIN_CITY               0.020886  0.003386    0.018438           NaN
# ORIGIN_STATE              0.016456  0.002896    0.016617           NaN
# ORIGIN_COUNTRY                 NaN       NaN         NaN           NaN
# DEST_AIRPORT              0.020975   0.00349    0.018519           NaN
# DEST_CITY                 0.020958  0.003485    0.018488           NaN
# DEST_STATE                0.016586  0.002991    0.016636           NaN
# DEST_COUNTRY                   NaN       NaN         NaN           NaN
# ARRIVAL_TIME_SEGMENT      0.031839  0.010301    0.037294           NaN
#
#                          FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT_CODE  \
# MONTH                          0.28379    0.085246            0.302169
# DAY                           0.090934    0.018074            0.006655
# DAY_OF_WEEK                   0.251289    0.017505            0.022212
# AIRLINE__CODE                      NaN         NaN                 NaN
# FLIGHT_NUMBER                      1.0    0.120603            0.298672
# TAIL_NUMBER                   0.120603         1.0              0.0475
# ORIGIN_AIRPORT_CODE           0.298672      0.0475                 1.0
# DESTINATION_AIRPORT_CODE      0.299757    0.047539            0.193408
# DIVERTED                           NaN         NaN                 NaN
# CANCELLED                          NaN         NaN                 NaN
# CANCELLATION_REASON                NaN         NaN                 NaN
# FLY_DATE                      0.109668    0.023495            0.076962
# AIRLINE                            NaN         NaN                 NaN
# ORIGIN_AIRPORT                0.349832    0.061505                 1.0
# ORIGIN_CITY                   0.349248    0.061795                 1.0
# ORIGIN_STATE                  0.347465    0.072802                 1.0
# ORIGIN_COUNTRY                     NaN         NaN                 NaN
# DEST_AIRPORT                  0.350441     0.06155            0.176712
# DEST_CITY                     0.350463    0.061841            0.177194
# DEST_STATE                    0.346209    0.072838            0.199861
# DEST_COUNTRY                       NaN         NaN                 NaN
# ARRIVAL_TIME_SEGMENT          0.346781    0.031813            0.141375
#
#                          DESTINATION_AIRPORT_CODE DIVERTED CANCELLED  \
# MONTH                                    0.302174      NaN       NaN
# DAY                                      0.006755      NaN       NaN
# DAY_OF_WEEK                              0.022263      NaN       NaN
# AIRLINE__CODE                                 NaN      NaN       NaN
# FLIGHT_NUMBER                            0.299757      NaN       NaN
# TAIL_NUMBER                              0.047539      NaN       NaN
# ORIGIN_AIRPORT_CODE                      0.193408      NaN       NaN
# DESTINATION_AIRPORT_CODE                      1.0      NaN       NaN
# DIVERTED                                      NaN      1.0       NaN
# CANCELLED                                     NaN      NaN       1.0
# CANCELLATION_REASON                           NaN      NaN       NaN
# FLY_DATE                                 0.076984      NaN       NaN
# AIRLINE                                       NaN      NaN       NaN
# ORIGIN_AIRPORT                           0.176712      NaN       NaN
# ORIGIN_CITY                              0.177192      NaN       NaN
# ORIGIN_STATE                             0.200018      NaN       NaN
# ORIGIN_COUNTRY                                NaN      NaN       NaN
# DEST_AIRPORT                                  1.0      NaN       NaN
# DEST_CITY                                     1.0      NaN       NaN
# DEST_STATE                                    1.0      NaN       NaN
# DEST_COUNTRY                                  NaN      NaN       NaN
# ARRIVAL_TIME_SEGMENT                     0.131204      NaN       NaN
#
#                          CANCELLATION_REASON  FLY_DATE AIRLINE ORIGIN_AIRPORT  \
# MONTH                                    NaN       1.0     NaN       0.020905
# DAY                                      NaN       1.0     NaN       0.003396
# DAY_OF_WEEK                              NaN       1.0     NaN       0.018471
# AIRLINE__CODE                            NaN       NaN     NaN            NaN
# FLIGHT_NUMBER                            NaN  0.109668     NaN       0.349832
# TAIL_NUMBER                              NaN  0.023495     NaN       0.061505
# ORIGIN_AIRPORT_CODE                      NaN  0.076962     NaN            1.0
# DESTINATION_AIRPORT_CODE                 NaN  0.076984     NaN       0.176712
# DIVERTED                                 NaN       NaN     NaN            NaN
# CANCELLED                                NaN       NaN     NaN            NaN
# CANCELLATION_REASON                      1.0       NaN     NaN            NaN
# FLY_DATE                                 NaN       1.0     NaN        0.01081
# AIRLINE                                  NaN       NaN     1.0            NaN
# ORIGIN_AIRPORT                           NaN   0.01081     NaN            1.0
# ORIGIN_CITY                              NaN  0.010855     NaN            1.0
# ORIGIN_STATE                             NaN  0.013105     NaN            1.0
# ORIGIN_COUNTRY                           NaN       NaN     NaN            NaN
# DEST_AIRPORT                             NaN  0.010974     NaN       0.176712
# DEST_CITY                                NaN   0.01102     NaN       0.177194
# DEST_STATE                               NaN  0.013354     NaN       0.199861
# DEST_COUNTRY                             NaN       NaN     NaN            NaN
# ARRIVAL_TIME_SEGMENT                     NaN  0.057835     NaN       0.138084
#
#                          ORIGIN_CITY ORIGIN_STATE ORIGIN_COUNTRY DEST_AIRPORT  \
# MONTH                       0.020886     0.016456            NaN     0.020975
# DAY                         0.003386     0.002896            NaN      0.00349
# DAY_OF_WEEK                 0.018438     0.016617            NaN     0.018519
# AIRLINE__CODE                    NaN          NaN            NaN          NaN
# FLIGHT_NUMBER               0.349248     0.347465            NaN     0.350441
# TAIL_NUMBER                 0.061795     0.072802            NaN      0.06155
# ORIGIN_AIRPORT_CODE              1.0          1.0            NaN     0.176712
# DESTINATION_AIRPORT_CODE    0.177192     0.200018            NaN          1.0
# DIVERTED                         NaN          NaN            NaN          NaN
# CANCELLED                        NaN          NaN            NaN          NaN
# CANCELLATION_REASON              NaN          NaN            NaN          NaN
# FLY_DATE                    0.010855     0.013105            NaN     0.010974
# AIRLINE                          NaN          NaN            NaN          NaN
# ORIGIN_AIRPORT                   1.0          1.0            NaN     0.176712
# ORIGIN_CITY                      1.0     0.987421            NaN     0.177192
# ORIGIN_STATE                0.987421          1.0            NaN     0.200018
# ORIGIN_COUNTRY                   NaN          NaN            1.0          NaN
# DEST_AIRPORT                0.177192     0.200018            NaN          1.0
# DEST_CITY                   0.176624     0.199031            NaN          1.0
# DEST_STATE                   0.19887     0.173305            NaN          1.0
# DEST_COUNTRY                     NaN          NaN            NaN          NaN
# ARRIVAL_TIME_SEGMENT        0.137208     0.115323            NaN     0.128671
#
#                          DEST_CITY DEST_STATE DEST_COUNTRY  \
# MONTH                     0.020958   0.016586          NaN
# DAY                       0.003485   0.002991          NaN
# DAY_OF_WEEK               0.018488   0.016636          NaN
# AIRLINE__CODE                  NaN        NaN          NaN
# FLIGHT_NUMBER             0.350463   0.346209          NaN
# TAIL_NUMBER               0.061841   0.072838          NaN
# ORIGIN_AIRPORT_CODE       0.177194   0.199861          NaN
# DESTINATION_AIRPORT_CODE       1.0        1.0          NaN
# DIVERTED                       NaN        NaN          NaN
# CANCELLED                      NaN        NaN          NaN
# CANCELLATION_REASON            NaN        NaN          NaN
# FLY_DATE                   0.01102   0.013354          NaN
# AIRLINE                        NaN        NaN          NaN
# ORIGIN_AIRPORT            0.177194   0.199861          NaN
# ORIGIN_CITY               0.176624    0.19887          NaN
# ORIGIN_STATE              0.199031   0.173305          NaN
# ORIGIN_COUNTRY                 NaN        NaN          NaN
# DEST_AIRPORT                   1.0        1.0          NaN
# DEST_CITY                      1.0   0.987421          NaN
# DEST_STATE                0.987421        1.0          NaN
# DEST_COUNTRY                   NaN        NaN          1.0
# ARRIVAL_TIME_SEGMENT      0.128214   0.113555          NaN
#
#                          ARRIVAL_TIME_SEGMENT
# MONTH                                0.031839
# DAY                                  0.010301
# DAY_OF_WEEK                          0.037294
# AIRLINE__CODE                             NaN
# FLIGHT_NUMBER                        0.346781
# TAIL_NUMBER                          0.031813
# ORIGIN_AIRPORT_CODE                  0.141375
# DESTINATION_AIRPORT_CODE             0.131204
# DIVERTED                                  NaN
# CANCELLED                                 NaN
# CANCELLATION_REASON                       NaN
# FLY_DATE                             0.057835
# AIRLINE                                   NaN
# ORIGIN_AIRPORT                       0.138084
# ORIGIN_CITY                          0.137208
# ORIGIN_STATE                         0.115323
# ORIGIN_COUNTRY                            NaN
# DEST_AIRPORT                         0.128671
# DEST_CITY                            0.128214
# DEST_STATE                           0.113555
# DEST_COUNTRY                              NaN
# ARRIVAL_TIME_SEGMENT                      1.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cramers_v_matrix = cramers_v_matrix.astype(float)

plt.figure(figsize=(8, 6))
sns.heatmap(cramers_v_matrix, annot=True, cmap="coolwarm", square=True)
plt.title("Cramér's V Correlation Matrix for Categorical Columns")
plt.show()

# %%
cramers_v_matrix
# Out:
#                              MONTH       DAY  DAY_OF_WEEK  AIRLINE__CODE  \
# MONTH                     1.000000  0.047854     0.044206            NaN
# DAY                       0.047854  1.000000     0.159043            NaN
# DAY_OF_WEEK               0.044206  0.159043     1.000000            NaN
# AIRLINE__CODE                  NaN       NaN          NaN            1.0
# FLIGHT_NUMBER             0.283790  0.090934     0.251289            NaN
# TAIL_NUMBER               0.085246  0.018074     0.017505            NaN
# ORIGIN_AIRPORT_CODE       0.302169  0.006655     0.022212            NaN
# DESTINATION_AIRPORT_CODE  0.302174  0.006755     0.022263            NaN
# DIVERTED                       NaN       NaN          NaN            NaN
# CANCELLED                      NaN       NaN          NaN            NaN
# CANCELLATION_REASON            NaN       NaN          NaN            NaN
# FLY_DATE                  1.000000  1.000000     1.000000            NaN
# AIRLINE                        NaN       NaN          NaN            NaN
# ORIGIN_AIRPORT            0.020905  0.003396     0.018471            NaN
# ORIGIN_CITY               0.020886  0.003386     0.018438            NaN
# ORIGIN_STATE              0.016456  0.002896     0.016617            NaN
# ORIGIN_COUNTRY                 NaN       NaN          NaN            NaN
# DEST_AIRPORT              0.020975  0.003490     0.018519            NaN
# DEST_CITY                 0.020958  0.003485     0.018488            NaN
# DEST_STATE                0.016586  0.002991     0.016636            NaN
# DEST_COUNTRY                   NaN       NaN          NaN            NaN
# ARRIVAL_TIME_SEGMENT      0.031839  0.010301     0.037294            NaN
#
#                           FLIGHT_NUMBER  TAIL_NUMBER  ORIGIN_AIRPORT_CODE  \
# MONTH                          0.283790     0.085246             0.302169
# DAY                            0.090934     0.018074             0.006655
# DAY_OF_WEEK                    0.251289     0.017505             0.022212
# AIRLINE__CODE                       NaN          NaN                  NaN
# FLIGHT_NUMBER                  1.000000     0.120603             0.298672
# TAIL_NUMBER                    0.120603     1.000000             0.047500
# ORIGIN_AIRPORT_CODE            0.298672     0.047500             1.000000
# DESTINATION_AIRPORT_CODE       0.299757     0.047539             0.193408
# DIVERTED                            NaN          NaN                  NaN
# CANCELLED                           NaN          NaN                  NaN
# CANCELLATION_REASON                 NaN          NaN                  NaN
# FLY_DATE                       0.109668     0.023495             0.076962
# AIRLINE                             NaN          NaN                  NaN
# ORIGIN_AIRPORT                 0.349832     0.061505             1.000000
# ORIGIN_CITY                    0.349248     0.061795             1.000000
# ORIGIN_STATE                   0.347465     0.072802             1.000000
# ORIGIN_COUNTRY                      NaN          NaN                  NaN
# DEST_AIRPORT                   0.350441     0.061550             0.176712
# DEST_CITY                      0.350463     0.061841             0.177194
# DEST_STATE                     0.346209     0.072838             0.199861
# DEST_COUNTRY                        NaN          NaN                  NaN
# ARRIVAL_TIME_SEGMENT           0.346781     0.031813             0.141375
#
#                           DESTINATION_AIRPORT_CODE  DIVERTED  CANCELLED  \
# MONTH                                     0.302174       NaN        NaN
# DAY                                       0.006755       NaN        NaN
# DAY_OF_WEEK                               0.022263       NaN        NaN
# AIRLINE__CODE                                  NaN       NaN        NaN
# FLIGHT_NUMBER                             0.299757       NaN        NaN
# TAIL_NUMBER                               0.047539       NaN        NaN
# ORIGIN_AIRPORT_CODE                       0.193408       NaN        NaN
# DESTINATION_AIRPORT_CODE                  1.000000       NaN        NaN
# DIVERTED                                       NaN       1.0        NaN
# CANCELLED                                      NaN       NaN        1.0
# CANCELLATION_REASON                            NaN       NaN        NaN
# FLY_DATE                                  0.076984       NaN        NaN
# AIRLINE                                        NaN       NaN        NaN
# ORIGIN_AIRPORT                            0.176712       NaN        NaN
# ORIGIN_CITY                               0.177192       NaN        NaN
# ORIGIN_STATE                              0.200018       NaN        NaN
# ORIGIN_COUNTRY                                 NaN       NaN        NaN
# DEST_AIRPORT                              1.000000       NaN        NaN
# DEST_CITY                                 1.000000       NaN        NaN
# DEST_STATE                                1.000000       NaN        NaN
# DEST_COUNTRY                                   NaN       NaN        NaN
# ARRIVAL_TIME_SEGMENT                      0.131204       NaN        NaN
#
#                           CANCELLATION_REASON  FLY_DATE  AIRLINE  \
# MONTH                                     NaN  1.000000      NaN
# DAY                                       NaN  1.000000      NaN
# DAY_OF_WEEK                               NaN  1.000000      NaN
# AIRLINE__CODE                             NaN       NaN      NaN
# FLIGHT_NUMBER                             NaN  0.109668      NaN
# TAIL_NUMBER                               NaN  0.023495      NaN
# ORIGIN_AIRPORT_CODE                       NaN  0.076962      NaN
# DESTINATION_AIRPORT_CODE                  NaN  0.076984      NaN
# DIVERTED                                  NaN       NaN      NaN
# CANCELLED                                 NaN       NaN      NaN
# CANCELLATION_REASON                       1.0       NaN      NaN
# FLY_DATE                                  NaN  1.000000      NaN
# AIRLINE                                   NaN       NaN      1.0
# ORIGIN_AIRPORT                            NaN  0.010810      NaN
# ORIGIN_CITY                               NaN  0.010855      NaN
# ORIGIN_STATE                              NaN  0.013105      NaN
# ORIGIN_COUNTRY                            NaN       NaN      NaN
# DEST_AIRPORT                              NaN  0.010974      NaN
# DEST_CITY                                 NaN  0.011020      NaN
# DEST_STATE                                NaN  0.013354      NaN
# DEST_COUNTRY                              NaN       NaN      NaN
# ARRIVAL_TIME_SEGMENT                      NaN  0.057835      NaN
#
#                           ORIGIN_AIRPORT  ORIGIN_CITY  ORIGIN_STATE  \
# MONTH                           0.020905     0.020886      0.016456
# DAY                             0.003396     0.003386      0.002896
# DAY_OF_WEEK                     0.018471     0.018438      0.016617
# AIRLINE__CODE                        NaN          NaN           NaN
# FLIGHT_NUMBER                   0.349832     0.349248      0.347465
# TAIL_NUMBER                     0.061505     0.061795      0.072802
# ORIGIN_AIRPORT_CODE             1.000000     1.000000      1.000000
# DESTINATION_AIRPORT_CODE        0.176712     0.177192      0.200018
# DIVERTED                             NaN          NaN           NaN
# CANCELLED                            NaN          NaN           NaN
# CANCELLATION_REASON                  NaN          NaN           NaN
# FLY_DATE                        0.010810     0.010855      0.013105
# AIRLINE                              NaN          NaN           NaN
# ORIGIN_AIRPORT                  1.000000     1.000000      1.000000
# ORIGIN_CITY                     1.000000     1.000000      0.987421
# ORIGIN_STATE                    1.000000     0.987421      1.000000
# ORIGIN_COUNTRY                       NaN          NaN           NaN
# DEST_AIRPORT                    0.176712     0.177192      0.200018
# DEST_CITY                       0.177194     0.176624      0.199031
# DEST_STATE                      0.199861     0.198870      0.173305
# DEST_COUNTRY                         NaN          NaN           NaN
# ARRIVAL_TIME_SEGMENT            0.138084     0.137208      0.115323
#
#                           ORIGIN_COUNTRY  DEST_AIRPORT  DEST_CITY  DEST_STATE  \
# MONTH                                NaN      0.020975   0.020958    0.016586
# DAY                                  NaN      0.003490   0.003485    0.002991
# DAY_OF_WEEK                          NaN      0.018519   0.018488    0.016636
# AIRLINE__CODE                        NaN           NaN        NaN         NaN
# FLIGHT_NUMBER                        NaN      0.350441   0.350463    0.346209
# TAIL_NUMBER                          NaN      0.061550   0.061841    0.072838
# ORIGIN_AIRPORT_CODE                  NaN      0.176712   0.177194    0.199861
# DESTINATION_AIRPORT_CODE             NaN      1.000000   1.000000    1.000000
# DIVERTED                             NaN           NaN        NaN         NaN
# CANCELLED                            NaN           NaN        NaN         NaN
# CANCELLATION_REASON                  NaN           NaN        NaN         NaN
# FLY_DATE                             NaN      0.010974   0.011020    0.013354
# AIRLINE                              NaN           NaN        NaN         NaN
# ORIGIN_AIRPORT                       NaN      0.176712   0.177194    0.199861
# ORIGIN_CITY                          NaN      0.177192   0.176624    0.198870
# ORIGIN_STATE                         NaN      0.200018   0.199031    0.173305
# ORIGIN_COUNTRY                       1.0           NaN        NaN         NaN
# DEST_AIRPORT                         NaN      1.000000   1.000000    1.000000
# DEST_CITY                            NaN      1.000000   1.000000    0.987421
# DEST_STATE                           NaN      1.000000   0.987421    1.000000
# DEST_COUNTRY                         NaN           NaN        NaN         NaN
# ARRIVAL_TIME_SEGMENT                 NaN      0.128671   0.128214    0.113555
#
#                           DEST_COUNTRY  ARRIVAL_TIME_SEGMENT
# MONTH                              NaN              0.031839
# DAY                                NaN              0.010301
# DAY_OF_WEEK                        NaN              0.037294
# AIRLINE__CODE                      NaN                   NaN
# FLIGHT_NUMBER                      NaN              0.346781
# TAIL_NUMBER                        NaN              0.031813
# ORIGIN_AIRPORT_CODE                NaN              0.141375
# DESTINATION_AIRPORT_CODE           NaN              0.131204
# DIVERTED                           NaN                   NaN
# CANCELLED                          NaN                   NaN
# CANCELLATION_REASON                NaN                   NaN
# FLY_DATE                           NaN              0.057835
# AIRLINE                            NaN                   NaN
# ORIGIN_AIRPORT                     NaN              0.138084
# ORIGIN_CITY                        NaN              0.137208
# ORIGIN_STATE                       NaN              0.115323
# ORIGIN_COUNTRY                     NaN                   NaN
# DEST_AIRPORT                       NaN              0.128671
# DEST_CITY                          NaN              0.128214
# DEST_STATE                         NaN              0.113555
# DEST_COUNTRY                       1.0                   NaN
# ARRIVAL_TIME_SEGMENT               NaN              1.000000

# %%
threshold = 0.6

high_association_columns = set()

for col in cramers_v_matrix.columns:
    high_values = cramers_v_matrix[col][cramers_v_matrix[col] > threshold]
    high_association_columns.update(high_values.index)

high_association_columns = list(high_association_columns)
print("Columns with Cramér's V > 0.5 with at least one other column:", high_association_columns)
# Out:
# Columns with Cramér's V > 0.5 with at least one other column: ['DAY_OF_WEEK', 'AIRLINE__CODE', 'ORIGIN_COUNTRY', 'ORIGIN_CITY', 'TAIL_NUMBER', 'CANCELLED', 'ORIGIN_STATE', 'MONTH', 'DEST_CITY', 'ORIGIN_AIRPORT', 'DEST_STATE', 'FLIGHT_NUMBER', 'DEST_COUNTRY', 'FLY_DATE', 'DESTINATION_AIRPORT_CODE', 'DIVERTED', 'ORIGIN_AIRPORT_CODE', 'ARRIVAL_TIME_SEGMENT', 'DEST_AIRPORT', 'AIRLINE', 'DAY', 'CANCELLATION_REASON']

# %% [markdown]
# # Define columns by data type

# %%
##numerical_cols = ['MONTH', 'DAY', 'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY',
 #                 'DISTANCE', 'SCHEDULED_ARRIVAL', 'DIVERTED', 'CANCELLED', 'AIR_SYSTEM_DELAY',
 #                 'SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY']
##categorical_cols = ['AIRLINE', 'ARRIVAL_TIME_SEGMENT']

numerical_cols = ['SCHEDULED_DEPARTURE', 'DISTANCE','SCHEDULED_ARRIVAL']                
#categorical_cols = ['MONTH', 'DAY', 'DAY_OF_WEEK', 'FLIGHT_NUMBER','TAIL_NUMBER',
#                    'AIRLINE', 'ORIGIN_AIRPORT', 'ORIGIN_CITY', 'DEST_AIRPORT', 'DEST_CITY','ARRIVAL_TIME_SEGMENT']
categorical_cols = ['ORIGIN_AIRPORT', 'FLIGHT_NUMBER', 'ORIGIN_AIRPORT_CODE', 'AIRLINE', 'ORIGIN_CITY', 'DAY', 'DAY_OF_WEEK',
                    'DIVERTED', 'DESTINATION_AIRPORT_CODE', 'CANCELLED', 'MONTH', 'FLY_DATE', 'CANCELLATION_REASON', 'ORIGIN_COUNTRY',
                    'ORIGIN_STATE', 'ARRIVAL_TIME_SEGMENT', 'DEST_COUNTRY', 'DEST_AIRPORT', 'DEST_CITY', 'DEST_STATE',
                    'TAIL_NUMBER', 'AIRLINE__CODE']

# %% [markdown]
# # Creating the target column

# %%
# result = []
# for row in flights_needed_data['ARRIVAL_DELAY']:
#   if row > 5:
#     result.append(1)
#   else:
#     result.append(0) 

# flights_needed_data['delay_flag'] = result
# flights_needed_data.value_counts('delay_flag')

# %%
flights_needed_data['MONTH'] = flights_needed_data['MONTH'].astype(int)

# %%
test_data = flights_needed_data[flights_needed_data['MONTH'] > 6] 
#test=test.drop(['FLY_DATE'], axis=1)
train_data = flights_needed_data[flights_needed_data['MONTH'] <= 6]

#train_data  = flights_needed_data[flights_needed_data["MONTH"].apply(lambda x: '11' not in x and '12' not in x)]
#test_data = flights_needed_data[flights_needed_data["MONTH"].apply(lambda x: '11' in x or '12' in x)]

# %%
train_data.shape, test_data.shape
# Out:
# ((610684, 46), (631719, 46))

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 631719 entries, 147468 to 5423102
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   YEAR                      631719 non-null  int16
#  1   MONTH                     631719 non-null  int64
#  2   DAY                       631719 non-null  object
#  3   DAY_OF_WEEK               631719 non-null  object
#  4   AIRLINE__CODE             631719 non-null  object
#  5   FLIGHT_NUMBER             631719 non-null  object
#  6   TAIL_NUMBER               631719 non-null  object
#  7   ORIGIN_AIRPORT_CODE       631719 non-null  object
#  8   DESTINATION_AIRPORT_CODE  631719 non-null  object
#  9   SCHEDULED_DEPARTURE       631719 non-null  int16
#  10  DEPARTURE_TIME            631719 non-null  float64
#  11  DEPARTURE_DELAY           631719 non-null  float64
#  12  TAXI_OUT                  631719 non-null  float64
#  13  WHEELS_OFF                631719 non-null  float64
#  14  SCHEDULED_TIME            631719 non-null  float64
#  15  ELAPSED_TIME              631719 non-null  float64
#  16  AIR_TIME                  631719 non-null  float64
#  17  DISTANCE                  631719 non-null  int16
#  18  WHEELS_ON                 631719 non-null  float64
#  19  TAXI_IN                   631719 non-null  float64
#  20  SCHEDULED_ARRIVAL         631719 non-null  int16
#  21  ARRIVAL_TIME              631719 non-null  float64
#  22  ARRIVAL_DELAY             631719 non-null  float64
#  23  DIVERTED                  631719 non-null  object
#  24  CANCELLED                 631719 non-null  object
#  25  CANCELLATION_REASON       0 non-null       object
#  26  AIR_SYSTEM_DELAY          113705 non-null  float64
#  27  SECURITY_DELAY            113705 non-null  float64
#  28  AIRLINE_DELAY             113705 non-null  float64
#  29  LATE_AIRCRAFT_DELAY       113705 non-null  float64
#  30  WEATHER_DELAY             113705 non-null  float64
#  31  FLY_DATE                  631719 non-null  object
#  32  AIRLINE                   631719 non-null  object
#  33  ORIGIN_AIRPORT            527666 non-null  object
#  34  ORIGIN_CITY               527666 non-null  object
#  35  ORIGIN_STATE              527666 non-null  object
#  36  ORIGIN_COUNTRY            527666 non-null  object
#  37  ORIGIN_LATITUDE           526929 non-null  float64
#  38  ORIGIN_LONGITUDE          526929 non-null  float64
#  39  DEST_AIRPORT              527666 non-null  object
#  40  DEST_CITY                 527666 non-null  object
#  41  DEST_STATE                527666 non-null  object
#  42  DEST_COUNTRY              527666 non-null  object
#  43  DEST_LATITUDE             526930 non-null  float64
#  44  DEST_LONGITUDE            526930 non-null  float64
#  45  ARRIVAL_TIME_SEGMENT      631719 non-null  object
# dtypes: float64(20), int16(4), int64(1), object(21)
# memory usage: 212.1+ MB

# %%
# Replace 'target_column_name' with the actual name of your target column
X_train = train_data.drop(columns=['ARRIVAL_DELAY'])
y_train = train_data['ARRIVAL_DELAY']

# Replace 'target_column_name' with the actual name of your target column
X_test = test_data.drop(columns=['ARRIVAL_DELAY'])
y_test = test_data['ARRIVAL_DELAY']

# %%
X_train.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE__CODE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT_CODE', 'DESTINATION_AIRPORT_CODE',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME', 'DIVERTED',
#        'CANCELLED', 'CANCELLATION_REASON', 'AIR_SYSTEM_DELAY',
#        'SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY',
#        'WEATHER_DELAY', 'FLY_DATE', 'AIRLINE', 'ORIGIN_AIRPORT', 'ORIGIN_CITY',
#        'ORIGIN_STATE', 'ORIGIN_COUNTRY', 'ORIGIN_LATITUDE', 'ORIGIN_LONGITUDE',
#        'DEST_AIRPORT', 'DEST_CITY', 'DEST_STATE', 'DEST_COUNTRY',
#        'DEST_LATITUDE', 'DEST_LONGITUDE', 'ARRIVAL_TIME_SEGMENT'],
#       dtype='object')

# %%
# numerical_cols = [ 'DISTANCE','AIR_TIME']                
# categorical_cols = ['MONTH', 'DAY', 'DAY_OF_WEEK', 'FLIGHT_NUMBER','TAIL_NUMBER',
#                     'AIRLINE', 'ORIGIN_AIRPORT', 'ORIGIN_CITY', 'DEST_AIRPORT', 'DEST_CITY','ARRIVAL_TIME_SEGMENT']
# ## should add flytime if rerunning again

# %%
##numerical_cols = ['MONTH', 'DAY', 'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY',
 #                 'DISTANCE', 'SCHEDULED_ARRIVAL', 'DIVERTED', 'CANCELLED', 'AIR_SYSTEM_DELAY',
 #                 'SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY']
##categorical_cols = ['AIRLINE', 'ARRIVAL_TIME_SEGMENT']

numerical_cols = ['SCHEDULED_DEPARTURE', 'DISTANCE','SCHEDULED_ARRIVAL', 'AIR_TIME']                
#categorical_cols = ['MONTH', 'DAY', 'DAY_OF_WEEK', 'FLIGHT_NUMBER','TAIL_NUMBER',
#                    'AIRLINE', 'ORIGIN_AIRPORT', 'ORIGIN_CITY', 'DEST_AIRPORT', 'DEST_CITY','ARRIVAL_TIME_SEGMENT']
categorical_cols = ['ORIGIN_AIRPORT', 'FLIGHT_NUMBER', 'AIRLINE',  'DAY', 'DAY_OF_WEEK', 'MONTH',  'ARRIVAL_TIME_SEGMENT',
                    'DEST_COUNTRY', 'DEST_AIRPORT']

# %% [markdown]
# # Define transformations for numerical columns: imputing and scaling

# %%
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# %% [markdown]
# # Define transformations for categorical columns: imputing and one-hot encoding

# %%
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

# %% [markdown]
# # Combine both transformations in a ColumnTransformer

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ]
)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
regressors = {
    'RandomForest': RandomForestRegressor(),
    'XGBoost': XGBRegressor(),
    'Ridge': Ridge(),
    'Lasso': Lasso(),
    'ElasticNet': ElasticNet(),
    'LinearRegression': LinearRegression(),
    'DecisionTree': DecisionTreeRegressor(),
    'KNeighbors': KNeighborsRegressor(),
    'SVR': SVR(),
    'GradientBoosting': GradientBoostingRegressor()
}

param_grid = {
    'RandomForest': {
        'regressor__n_estimators': [100, 200],
        'regressor__max_depth': [5, 10]
    },
    'XGBoost': {
        'regressor__n_estimators': [100, 200],
        'regressor__learning_rate': [0.1, 0.3],
        'regressor__max_depth': [3, 10],
        'regressor__subsample': [0.5, 1.0]
    },
    'Ridge': {
        'regressor__alpha': [1.0, 10.0, 100.0]
    },
    'Lasso': {
        'regressor__alpha': [0.1, 1.0, 10.0]
    },
    'ElasticNet': {
        'regressor__alpha': [0.1, 1.0, 10.0],
        'regressor__l1_ratio': [0.2, 0.5, 0.8]
    },
    'LinearRegression': {},  # No hyperparameters to tune
    'DecisionTree': {
        'regressor__max_depth': [5, 10, 15]
    },
    'KNeighbors': {
        'regressor__n_neighbors': [3, 5, 7]
    },
    'SVR': {
        'regressor__C': [0.1, 1.0, 10.0],
        'regressor__kernel': ['linear', 'rbf']
    },
    'GradientBoosting': {
        'regressor__n_estimators': [100, 200],
        'regressor__learning_rate': [0.1, 0.3],
        'regressor__max_depth': [3, 5]
    }
}

# Initialize variables to store the best model and score
best_model = None
best_score = float('-inf')
best_params = None

# %%
for name, regressor in regressors.items():
    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('regressor', regressor)
    ])
    
    # Perform grid search
    grid_search = GridSearchCV(pipeline, param_grid[name], cv=5, scoring='r2', n_jobs=-1)
    grid_search.fit(X_train, y_train)
    
    # Check if this model is the best so far
    if grid_search.best_score_ > best_score:
        best_score = grid_search.best_score_
        best_model = grid_search.best_estimator_
        best_params = grid_search.best_params_

    print(f"Model: {name}")
    print(f"Best R² score from cross-validation: {grid_search.best_score_}")
    print(f"Best parameters: {grid_search.best_params_}")
    print("")

# Output the best model and its parameters
print("Best model overall:")
print(best_model)
print(f"Best cross-validation R² score: {best_score}")
print(f"Best parameters: {best_params}")

# Evaluate on the test set
y_pred = best_model.predict(X_test)
test_mse = mean_squared_error(y_test, y_pred)
test_r2 = r2_score(y_test, y_pred)

print(f"Test set MSE: {test_mse}")
print(f"Test set R² score: {test_r2}")
# Out:
# Model: RandomForest
# Best R² score from cross-validation: 0.016386071702111794
# Best parameters: {'regressor__max_depth': 5, 'regressor__n_estimators': 100}

# %%
# from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


# pipeline.fit(X_train, y_train)

# y_train_pred = pipeline.predict(X_train)

# train_mse = mean_squared_error(y_train, y_train_pred)
# train_mae = mean_absolute_error(y_train, y_train_pred)
# train_r2 = r2_score(y_train, y_train_pred)

# print(f"Training MSE: {train_mse}")
# print(f"Training MAE: {train_mae}")
# print(f"Training R²: {train_r2}")


# y_test_pred = pipeline.predict(X_test)

# test_mse = mean_squared_error(y_test, y_test_pred)
# test_mae = mean_absolute_error(y_test, y_test_pred)
# test_r2 = r2_score(y_test, y_test_pred)

# print(f"Test MSE: {test_mse}")
# print(f"Test MAE: {test_mae}")
# print(f"Test R²: {test_r2}")


# mse_tolerance = 0.2 

# if train_mse < test_mse * (1 - mse_tolerance) and train_r2 > test_r2:
#     print("The model is likely overfitting.")
# elif train_mse > test_mse * (1 + mse_tolerance):
#     print("The model is likely underfitting.")
# else:
#     print("The model is likely generalizing well.")
